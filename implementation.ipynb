# %% [markdown]
# ## 1. On-premises Algorithm
# ### Scalable Similarity Graph Summary
#
# This notebook builds and queries a top-k similarity graph using two approaches:
#
# 1. **MinHashLSH-Based Graph (`ScalableSimilarityGraph`)**
#    - Tokenizes text and generates MinHash signatures
#    - Inserts documents into an LSH index
#    - Computes true Jaccard similarity with LSH candidates
#    - Maintains top-k neighbors using a heap per document
#
# 2. **Precomputed Matrix Graph (`PrecomputedSimilarityGraph`)**
#    - Loads full or partial similarity matrices (e.g., from CSV)
#    - Builds top-k neighbor lists from static similarity scores
#    - Supports dynamic insertion of new documents using precomputed similarity vectors
#
# Also includes utilities to:
# - Preprocess text
# - Load/save similarity graphs (JSON)
# - Import similarity matrices (CSV)
#
# ## Assumptions
#
# - We assume all documents and their embeddings fit on a **single machine** (i.e., non-distributed setup).
# - The **similarity matrix** is precomputed using **cosine similarity** between normalized document embeddings.
# - Each document has a unique ID and is compared to every other document.
# - We aim to maintain a **top-k neighbor list per document**, using a min-heap to store the most similar entries.
#
# ---
#
# ### Time and Space Complexity Analysis
#
# Let:
# - `n` = number of documents
# - `d` = dimensionality of each document vector (e.g., SBERT embedding)
# - `k` = number of top neighbors per document (e.g., 5)
#
# ### Time Complexity
#
# - **Cosine Similarity Matrix Computation**:
#   - Dot product for all pairs of `n` vectors:
#     \[
#     O(n^2 \cdot d)
#     \]
# - **Heap-based Top-k Construction** (per document):
#   - For each row, push `n` entries and keep top-k:
#     \[
#     O(n \cdot \log k)
#     \]
#   - Across all documents:
#     \[
#     O(n^2 \cdot \log k)
#     \]
#
# ➡️ **Total Time:**
# \[
# \boxed{O(n^2 \cdot (d + \log k))}
# \]
#
# ---
#
# ### Space Complexity
#
# - **Embedding storage:**
#   \[
#   O(n \cdot d)
#   \]
# - **Similarity matrix:**
#   \[
#   O(n^2)
#   \]
# - **Top-k heaps:**
#   \[
#   O(n \cdot k)
#   \]
#
# ➡️ **Total Space:**
# \[
# \boxed{O(n^2 + n \cdot d)}
# \]
#
# ---
#
# > ⚠️ This method is feasible only for moderate `n` (e.g., n ≤ 10,000). For larger datasets, distributed or approximate methods (e.g., Faiss, HNSW, or LSH) are recommended.

# %%
import heapq
import re
from datasketch import MinHash, MinHashLSH
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# --------- Utilities ---------
def preprocess(text):
    """Simple text cleaning and tokenization."""
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s]', '', text)
    tokens = text.split()
    tokens = [token for token in tokens if token not in ENGLISH_STOP_WORDS]
    return set(tokens)

def minhash_doc(tokens, num_perm=128):
    """Generate MinHash signature for a set of tokens."""
    m = MinHash(num_perm=num_perm)
    for token in tokens:
        m.update(token.encode('utf8'))
    return m

# --------- Main Graph Class ---------
class ScalableSimilarityGraph:
    def __init__(self, threshold=0.5, top_k=5, num_perm=128):
        self.threshold = threshold
        self.top_k = top_k
        self.num_perm = num_perm
        
        self.lsh = MinHashLSH(threshold=self.threshold, num_perm=self.num_perm)
        self.doc_signatures = {}  # doc_id -> MinHash signature
        self.doc_tokens = {}  # doc_id -> token set (for true Jaccard)
        self.graph = {}  # doc_id -> min-heap of (similarity, neighbor_doc_id)
    
    def add_document(self, doc_id, text):
        """Insert a new document dynamically."""
        tokens = preprocess(text)
        signature = minhash_doc(tokens, self.num_perm)
        
        self.doc_signatures[doc_id] = signature
        self.doc_tokens[doc_id] = tokens
        self.graph[doc_id] = []  # initialize heap
        self.lsh.insert(doc_id, signature)
        
        candidates = self.lsh.query(signature)
        
        for existing_id in candidates:
            if existing_id == doc_id:
                continue
            true_sim = self.true_jaccard(doc_id, existing_id)
            
            # Update new doc's heap
            heapq.heappush(self.graph[doc_id], (true_sim, existing_id))
            if len(self.graph[doc_id]) > self.top_k:
                heapq.heappop(self.graph[doc_id])
            
            # Update existing doc's heap
            heapq.heappush(self.graph[existing_id], (true_sim, doc_id))
            if len(self.graph[existing_id]) > self.top_k:
                heapq.heappop(self.graph[existing_id])
    
    def true_jaccard(self, doc_id1, doc_id2):
        """Calculate true Jaccard similarity between two sets."""
        set1 = self.doc_tokens[doc_id1]
        set2 = self.doc_tokens[doc_id2]
        intersection = set1.intersection(set2)
        union = set1.union(set2)
        if not union:
            return 0
        return len(intersection) / len(union)
    
    def get_top_neighbors(self, doc_id):
        """Return sorted top neighbors (highest similarity first)."""
        return sorted(self.graph.get(doc_id, []), reverse=True)

    def all_documents(self):
        """Return list of all document IDs."""
        return list(self.graph.keys())

# %%
class FullMatrixImporter:
    @staticmethod
    def import_full_matrix(similarity_graph, sim_matrix, doc_ids):
        """
        similarity_graph: instance of ScalableSimilarityGraph
        sim_matrix: 2D list or numpy array (full symmetric similarity matrix)
        doc_ids: list of document IDs corresponding to matrix rows/columns
        """
        n = len(doc_ids)
        
        # Initialize heaps if not already
        for doc_id in doc_ids:
            if doc_id not in similarity_graph.graph:
                similarity_graph.graph[doc_id] = []
        
        # Traverse full matrix
        for i in range(n):
            for j in range(n):
                if i == j:
                    continue  # skip self-comparison
                sim = sim_matrix[i][j]
                if sim is None:
                    continue
                doc_i = doc_ids[i]
                doc_j = doc_ids[j]
                
                # Add neighbor for doc_i
                heapq.heappush(similarity_graph.graph[doc_i], (sim, doc_j))
                if len(similarity_graph.graph[doc_i]) > similarity_graph.top_k:
                    heapq.heappop(similarity_graph.graph[doc_i])

# %%
import csv

def load_similarity_matrix_from_csv(file_path):
    """
    Loads a full similarity matrix from CSV.
    Returns (doc_ids, similarity_matrix)
    """
    with open(file_path, newline='') as csvfile:
        reader = csv.reader(csvfile)
        rows = list(reader)
        
        # First row contains column headers (skip the first blank cell)
        doc_ids = rows[0][1:]  # skip top-left blank
        
        similarity_matrix = []
        
        # Remaining rows: first column is row doc_id, rest are scores
        for row in rows[1:]:
            scores = [float(x) for x in row[1:]]  # skip row header
            similarity_matrix.append(scores)
    
    return doc_ids, similarity_matrix

# %%
import json

def save_graph_to_json(similarity_graph, file_path):
    output = {}
    for doc_id, neighbors in similarity_graph.graph.items():
        # Save list of neighbor tuples
        output[doc_id] = [{"neighbor": neighbor_id, "similarity": sim} for sim, neighbor_id in sorted(neighbors, reverse=True)]
    
    with open(file_path, "w") as f:
        json.dump(output, f, indent=2)

def load_graph_from_json(file_path):
    with open(file_path, "r") as f:
        return json.load(f)

# %%
# Step 1: Load CSV
csv_file_path = "/Users/renkhunag/Desktop/Spring25/DS563/final_project/scores/similarity_matrix_full.csv"  # replace with your actual CSV file path
doc_ids, sim_matrix = load_similarity_matrix_from_csv(csv_file_path)

# Step 2: Initialize graph
similarity_graph = ScalableSimilarityGraph(threshold=0.5, top_k=5)

# Step 3: Import from loaded matrix
FullMatrixImporter.import_full_matrix(similarity_graph, sim_matrix, doc_ids)

# Step 4: Query top neighbors
for doc_id in doc_ids:
    print(f"\nTop neighbors for {doc_id}:")
    for sim, neighbor in similarity_graph.get_top_neighbors(doc_id):
        print(f" - {neighbor} (Similarity: {sim:.2f})")
# Out:
# Top neighbors for ita0037_0.pdf:
#  - italaw7777.pdf (Similarity: 0.80)
#  - ita0244.pdf (Similarity: 0.71)
#  - ita0133_0.pdf (Similarity: 0.69)
#  - ita0924.pdf (Similarity: 0.51)
#  - ita0926.pdf (Similarity: 0.50)
#
# Top neighbors for italaw8418.pdf:
#  - italaw9532_0.pdf (Similarity: 1.00)
#  - italaw9531.pdf (Similarity: 1.00)
#  - italaw9530.pdf (Similarity: 1.00)
#  - italaw9529_0.pdf (Similarity: 1.00)
#  - italaw9528.pdf (Similarity: 1.00)
#
# Top neighbors for italaw4264.pdf:
#  - italaw4260.pdf (Similarity: 0.61)
#  - italaw7399_11.pdf (Similarity: 0.53)
#  - italaw7401.pdf (Similarity: 0.53)
#  - italaw7306.pdf (Similarity: 0.51)
#  - italaw4297.pdf (Similarity: 0.49)
#
# Top neighbors for italaw9571.pdf:
#  - italaw9590.pdf (Similarity: 0.80)
#  - italaw9591_0.pdf (Similarity: 0.73)
#  - italaw9574.pdf (Similarity: 0.71)
#  - italaw9600_0.pdf (Similarity: 0.70)
#  - italaw9575.pdf (Similarity: 0.68)
#
# Top neighbors for italaw182159.pdf:
#  - italaw182163.pdf (Similarity: 1.00)
#  - italaw182160.pdf (Similarity: 1.00)
#  - italaw171100.pdf (Similarity: 0.61)
#  - italaw171099.pdf (Similarity: 0.59)
#  - italaw170885.pdf (Similarity: 0.58)
#
# Top neighbors for italaw1437.pdf:
#  - italaw1439.pdf (Similarity: 0.80)
#  - italaw1449.pdf (Similarity: 0.70)
#  - italaw3035.pdf (Similarity: 0.69)
#  - italaw10317.pdf (Similarity: 0.69)
#  - italaw8131.pdf (Similarity: 0.65)
#
# Top neighbors for italaw4005.pdf:
#  - italaw1185.pdf (Similarity: 0.41)
#  - italaw8836.pdf (Similarity: 0.35)
#  - italaw4484.pdf (Similarity: 0.32)
#  - italaw4176.pdf (Similarity: 0.30)
#  - italaw171173.pdf (Similarity: 0.29)
#
# Top neighbors for italaw7677.pdf:
#  - italaw10120.pdf (Similarity: 0.62)
#  - italaw10121.pdf (Similarity: 0.58)
#  - italaw170721.pdf (Similarity: 0.46)
#  - italaw10122.pdf (Similarity: 0.39)
#  - italaw181986.pdf (Similarity: 0.37)
#
# Top neighbors for italaw7537.pdf:
#  - italaw7533_0.pdf (Similarity: 0.44)
#  - italaw4299.pdf (Similarity: 0.41)
#  - italaw10103.pdf (Similarity: 0.40)
#  - italaw10102.pdf (Similarity: 0.40)
#  - italaw7291.pdf (Similarity: 0.38)
#
# Top neighbors for italaw9014.pdf:
#  - italaw8482.pdf (Similarity: 0.84)
#  - italaw7064.pdf (Similarity: 0.77)
#  - italaw4458.pdf (Similarity: 0.71)
#  - italaw8484.pdf (Similarity: 0.70)
#  - italaw11133_0.pdf (Similarity: 0.67)
#
# Top neighbors for italaw182402.pdf:
#  - italaw182411.pdf (Similarity: 0.52)
#  - italaw182412.pdf (Similarity: 0.50)
#  - italaw4297.pdf (Similarity: 0.48)
#  - italaw1576.pdf (Similarity: 0.47)
#  - italaw171122.pdf (Similarity: 0.46)
#
# Top neighbors for italaw9129.pdf:
#  - italaw9139.pdf (Similarity: 1.00)
#  - italaw9147.pdf (Similarity: 0.50)
#  - italaw9134.pdf (Similarity: 0.49)
#  - italaw9156.pdf (Similarity: 0.49)
#  - italaw9157.pdf (Similarity: 0.46)
#
# Top neighbors for italaw3014.pdf:
#  - italaw3013.pdf (Similarity: 0.48)
#  - ita0142.pdf (Similarity: 0.40)
#  - ita0538.pdf (Similarity: 0.37)
#  - ita0101.pdf (Similarity: 0.31)
#  - italaw1277.pdf (Similarity: 0.28)
#
# Top neighbors for ita0210.pdf:
#  - ita0206.pdf (Similarity: 0.76)
#  - ita0221.pdf (Similarity: 0.56)
#  - ita0215.pdf (Similarity: 0.48)
#  - ita0214.pdf (Similarity: 0.47)
#  - ita0299.pdf (Similarity: 0.44)
#
# Top neighbors for italaw6352.pdf:
#  - italaw6354.pdf (Similarity: 0.65)
#  - italaw4043.pdf (Similarity: 0.29)
#  - ita0864.pdf (Similarity: 0.28)
#  - ita0538.pdf (Similarity: 0.28)
#  - italaw9383.pdf (Similarity: 0.27)
#
# Top neighbors for 180590.pdf:
#  - 180129.pdf (Similarity: 0.84)
#  - 180492.pdf (Similarity: 0.80)
#  - 180770.pdf (Similarity: 0.79)
#  - italaw180931.pdf (Similarity: 0.79)
#  - italaw180932.pdf (Similarity: 0.77)
#
# Top neighbors for ita0067.pdf:
#  - italaw10617.pdf (Similarity: 0.47)
#  - italaw10614.pdf (Similarity: 0.38)
#  - italaw10616_0.pdf (Similarity: 0.27)
#  - italaw9852_0.pdf (Similarity: 0.23)
#  - ita0553.pdf (Similarity: 0.23)
#
# Top neighbors for italaw181743.pdf:
#  - italaw181745.pdf (Similarity: 0.68)
#  - italaw16372.pdf (Similarity: 0.60)
#  - italaw16420.pdf (Similarity: 0.43)
#  - italaw16421.pdf (Similarity: 0.40)
#  - italaw171045.pdf (Similarity: 0.37)
#
# Top neighbors for italaw170238.pdf:
#  - italaw170401.pdf (Similarity: 0.31)
#  - italaw170241.pdf (Similarity: 0.29)
#  - italaw170230.pdf (Similarity: 0.29)
#  - italaw171189.pdf (Similarity: 0.26)
#  - italaw170236.pdf (Similarity: 0.24)
#
# Top neighbors for 180550.pdf:
#  - italaw180882.pdf (Similarity: 0.87)
#  - 180655.pdf (Similarity: 0.87)
#  - 180237.pdf (Similarity: 0.86)
#  - italaw170597.pdf (Similarity: 0.85)
#  - italaw7482.pdf (Similarity: 0.74)
#
# Top neighbors for ita0221.pdf:
#  - ita0214.pdf (Similarity: 0.68)
#  - ita0215.pdf (Similarity: 0.61)
#  - italaw7090.pdf (Similarity: 0.59)
#  - ita0210.pdf (Similarity: 0.56)
#  - italaw10153.pdf (Similarity: 0.54)
#
# Top neighbors for italaw10036.pdf:
#  - italaw10024.pdf (Similarity: 0.84)
#  - italaw8472.pdf (Similarity: 0.60)
#  - italaw10044.pdf (Similarity: 0.56)
#  - italaw10046.pdf (Similarity: 0.53)
#  - italaw10439.pdf (Similarity: 0.51)
#
# Top neighbors for italaw10120.pdf:
#  - italaw7677.pdf (Similarity: 0.62)
#  - italaw10121.pdf (Similarity: 0.54)
#  - italaw170721.pdf (Similarity: 0.46)
#  - italaw180930_0.pdf (Similarity: 0.45)
#  - italaw16584.pdf (Similarity: 0.39)
#
# Top neighbors for italaw4176.pdf:
#  - italaw1185.pdf (Similarity: 0.47)
#  - italaw8836.pdf (Similarity: 0.43)
#  - italaw4484.pdf (Similarity: 0.38)
#  - ita0458.pdf (Similarity: 0.35)
#  - italaw8574.pdf (Similarity: 0.34)
#
# Top neighbors for italaw1239.pdf:
#  - italaw8930.pdf (Similarity: 0.60)
#  - italaw1183.pdf (Similarity: 0.58)
#  - 180092.pdf (Similarity: 0.56)
#  - italaw10632.pdf (Similarity: 0.56)
#  - italaw3175.pdf (Similarity: 0.55)
#
# Top neighbors for ita1023.pdf:
#  - italaw7120.pdf (Similarity: 1.00)
#  - ita1024.pdf (Similarity: 1.00)
#  - italaw7131.pdf (Similarity: 0.44)
#  - italaw7121.pdf (Similarity: 0.44)
#  - italaw7139.pdf (Similarity: 0.44)
#
# Top neighbors for italaw11269.pdf:
#  - italaw11268.pdf (Similarity: 0.75)
#  - italaw11270.pdf (Similarity: 0.59)
#  - italaw11434.pdf (Similarity: 0.51)
#  - italaw11426_0.pdf (Similarity: 0.50)
#  - italaw11429.pdf (Similarity: 0.49)
#
# Top neighbors for 180597.pdf:
#  - 180595.pdf (Similarity: 0.92)
#  - 180596.pdf (Similarity: 0.90)
#  - italaw182573.pdf (Similarity: 0.82)
#  - italaw182574.pdf (Similarity: 0.81)
#  - 180593.pdf (Similarity: 0.79)
#
# Top neighbors for ita0145.pdf:
#  - ita0144.pdf (Similarity: 0.58)
#  - italaw182243.pdf (Similarity: 0.47)
#  - italaw182239.pdf (Similarity: 0.47)
#  - ita0146_0.pdf (Similarity: 0.43)
#  - italaw182242.pdf (Similarity: 0.42)
#
# Top neighbors for italaw9769_1.pdf:
#  - italaw9773.pdf (Similarity: 0.85)
#  - italaw9768_0.pdf (Similarity: 0.70)
#  - italaw6210_0.pdf (Similarity: 0.65)
#  - italaw1145.pdf (Similarity: 0.63)
#  - ITA%20LAW%207026.pdf (Similarity: 0.63)
#
# Top neighbors for italaw170811.pdf:
#  - italaw16553_0.pdf (Similarity: 0.50)
#  - italaw16553.pdf (Similarity: 0.50)
#  - italaw8933.pdf (Similarity: 0.42)
#  - italaw9767_0.pdf (Similarity: 0.38)
#  - italaw16551_0.pdf (Similarity: 0.37)
#
# Top neighbors for italaw7621.pdf:
#  - italaw7619.pdf (Similarity: 0.41)
#  - italaw7617.pdf (Similarity: 0.40)
#  - italaw7620_1.pdf (Similarity: 0.38)
#  - italaw9718.pdf (Similarity: 0.37)
#  - italaw10320.pdf (Similarity: 0.37)
#
# Top neighbors for italaw180931.pdf:
#  - 180770.pdf (Similarity: 0.94)
#  - 180492.pdf (Similarity: 0.93)
#  - 180590.pdf (Similarity: 0.79)
#  - italaw16009.pdf (Similarity: 0.72)
#  - italaw180932.pdf (Similarity: 0.72)
#
# Top neighbors for italaw8875.pdf:
#  - italaw8878.pdf (Similarity: 0.70)
#  - italaw8871_1.pdf (Similarity: 0.64)
#  - italaw8870.pdf (Similarity: 0.63)
#  - italaw8877.pdf (Similarity: 0.62)
#  - italaw8861.pdf (Similarity: 0.55)
#
# Top neighbors for ita0259_0.pdf:
#  - ita0260_0.pdf (Similarity: 0.65)
#  - italaw7777.pdf (Similarity: 0.52)
#  - ita0037_0.pdf (Similarity: 0.46)
#  - italaw8038.pdf (Similarity: 0.43)
#  - italaw3030_1.pdf (Similarity: 0.38)
#
# Top neighbors for italaw182047.pdf:
#  - italaw181526.pdf (Similarity: 0.54)
#  - italaw181523.pdf (Similarity: 0.54)
#  - italaw181525.pdf (Similarity: 0.53)
#  - italaw181524.pdf (Similarity: 0.49)
#  - italaw181522.pdf (Similarity: 0.47)
#
# Top neighbors for italaw8707.pdf:
#  - italaw8710.pdf (Similarity: 0.75)
#  - italaw8706.pdf (Similarity: 0.71)
#  - ita0118.pdf (Similarity: 0.71)
#  - ita0120.pdf (Similarity: 0.70)
#  - italaw8713.pdf (Similarity: 0.70)
#
# Top neighbors for 180090.pdf:
#  - italaw11278.pdf (Similarity: 0.92)
#  - italaw10143_0_0.pdf (Similarity: 0.75)
#  - italaw11597.pdf (Similarity: 0.67)
#  - italaw16469.pdf (Similarity: 0.65)
#  - 180129.pdf (Similarity: 0.63)
#
# Top neighbors for italaw11555.pdf:
#  - italaw11375.pdf (Similarity: 0.60)
#  - italaw11630.pdf (Similarity: 0.45)
#  - italaw16216.pdf (Similarity: 0.44)
#  - italaw11373.pdf (Similarity: 0.41)
#  - ita0240.pdf (Similarity: 0.38)
#
# Top neighbors for italaw182562.pdf:
#  - italaw182561.pdf (Similarity: 0.81)
#  - italaw171336.pdf (Similarity: 0.80)
#  - italaw171342.pdf (Similarity: 0.78)
#  - italaw11478_0.pdf (Similarity: 0.76)
#  - italaw182564.pdf (Similarity: 0.75)
#
# Top neighbors for 180369.pdf:
#  - 180365.pdf (Similarity: 0.64)
#  - italaw16346.pdf (Similarity: 0.63)
#  - italaw170960.pdf (Similarity: 0.59)
#  - italaw182024.pdf (Similarity: 0.59)
#  - italaw171332.pdf (Similarity: 0.58)
#
# Top neighbors for italaw7753.pdf:
#  - italaw7754.pdf (Similarity: 1.00)
#  - italaw7752.pdf (Similarity: 1.00)
#  - italaw7748_0.pdf (Similarity: 0.72)
#  - italaw7747_0.pdf (Similarity: 0.72)
#  - italaw7746_0.pdf (Similarity: 0.72)
#
# Top neighbors for italaw9908.pdf:
#  - italaw11394.pdf (Similarity: 0.64)
#  - italaw9761.pdf (Similarity: 0.58)
#  - italaw11396.pdf (Similarity: 0.52)
#  - italaw11395.pdf (Similarity: 0.48)
#  - italaw171027.pdf (Similarity: 0.46)
#
# Top neighbors for italaw7990_0.pdf:
#  - italaw7989.pdf (Similarity: 0.75)
#  - ita0104.pdf (Similarity: 0.57)
#  - ita0623.pdf (Similarity: 0.52)
#  - italaw8028_0.pdf (Similarity: 0.48)
#  - italaw7939_0.pdf (Similarity: 0.45)
#
# Top neighbors for ITA%20LAW%207015.pdf:
#  - italaw4132.pdf (Similarity: 0.83)
#  - italaw4150.pdf (Similarity: 0.81)
#  - italaw4377.pdf (Similarity: 0.81)
#  - italaw4138.pdf (Similarity: 0.72)
#  - italaw1172.pdf (Similarity: 0.69)
#
# Top neighbors for ita0917.pdf:
#  - ita0860.pdf (Similarity: 0.64)
#  - ita0915.pdf (Similarity: 0.61)
#  - ita0918.pdf (Similarity: 0.61)
#  - italaw9724.pdf (Similarity: 0.57)
#  - italaw11128.pdf (Similarity: 0.53)
#
# Top neighbors for italaw11377.pdf:
#  - italaw11379.pdf (Similarity: 0.78)
#  - italaw11284.pdf (Similarity: 0.30)
#  - italaw11282.pdf (Similarity: 0.28)
#  - italaw10817.pdf (Similarity: 0.27)
#  - 180253.pdf (Similarity: 0.26)
#
# Top neighbors for italaw4148.pdf:
#  - italaw1582.pdf (Similarity: 0.56)
#  - italaw4149.pdf (Similarity: 0.55)
#  - italaw4142.pdf (Similarity: 0.52)
#  - italaw4046.pdf (Similarity: 0.51)
#  - italaw1530.pdf (Similarity: 0.50)
#
# Top neighbors for italaw171032.pdf:
#  - italaw170388.pdf (Similarity: 0.28)
#  - italaw180900.pdf (Similarity: 0.28)
#  - italaw180899.pdf (Similarity: 0.28)
#  - italaw180855.pdf (Similarity: 0.27)
#  - italaw180854.pdf (Similarity: 0.27)
#
# Top neighbors for 180183.pdf:
#  - 180178.pdf (Similarity: 1.00)
#  - 180181.pdf (Similarity: 0.99)
#  - 180180.pdf (Similarity: 0.92)
#  - 180171.pdf (Similarity: 0.56)
#  - 180190.pdf (Similarity: 0.54)
#
# Top neighbors for italaw10103.pdf:
#  - italaw10102.pdf (Similarity: 1.00)
#  - italaw7511.pdf (Similarity: 0.73)
#  - italaw7866.pdf (Similarity: 0.68)
#  - italaw4299.pdf (Similarity: 0.67)
#  - italaw8833.pdf (Similarity: 0.64)
#
# Top neighbors for italaw11176.pdf:
#  - italaw182105.pdf (Similarity: 0.66)
#  - italaw16202.pdf (Similarity: 0.63)
#  - italaw11342.pdf (Similarity: 0.61)
#  - 180105.pdf (Similarity: 0.61)
#  - italaw11348.pdf (Similarity: 0.59)
#
# Top neighbors for italaw9745.pdf:
#  - italaw8028_0.pdf (Similarity: 0.53)
#  - italaw7939_0.pdf (Similarity: 0.50)
#  - ita0477.pdf (Similarity: 0.50)
#  - ita0623.pdf (Similarity: 0.49)
#  - italaw16050.pdf (Similarity: 0.46)
#
# Top neighbors for italaw4345.pdf:
#  - italaw4032.pdf (Similarity: 0.83)
#  - italaw4173.pdf (Similarity: 0.63)
#  - italaw4166.pdf (Similarity: 0.62)
#  - italaw4059.pdf (Similarity: 0.60)
#  - italaw4170.pdf (Similarity: 0.59)
#
# Top neighbors for italaw7248.pdf:
#  - italaw7256.pdf (Similarity: 1.00)
#  - italaw7254_3.pdf (Similarity: 1.00)
#  - italaw4158_0.pdf (Similarity: 0.39)
#  - ita0891.pdf (Similarity: 0.36)
#  - ita0910.pdf (Similarity: 0.35)
#
# Top neighbors for italaw8135_8.pdf:
#  - italaw4101.pdf (Similarity: 0.79)
#  - ita0405.pdf (Similarity: 0.64)
#  - italaw4226.pdf (Similarity: 0.32)
#  - ita0907.pdf (Similarity: 0.31)
#  - ita0416.pdf (Similarity: 0.31)
#
# Top neighbors for italaw9190.pdf:
#  - italaw9191.pdf (Similarity: 1.00)
#  - italaw9189.pdf (Similarity: 1.00)
#  - italaw7502.pdf (Similarity: 0.64)
#  - italaw180821.pdf (Similarity: 0.59)
#  - 180393.pdf (Similarity: 0.57)
#
# Top neighbors for italaw10358.pdf:
#  - italaw11207_0.pdf (Similarity: 0.61)
#  - italaw9007.pdf (Similarity: 0.59)
#  - italaw3227.pdf (Similarity: 0.56)
#  - italaw11523.pdf (Similarity: 0.54)
#  - italaw10427.pdf (Similarity: 0.52)
#
# Top neighbors for italaw182331.pdf:
#  - italaw182332.pdf (Similarity: 0.61)
#  - ita0538.pdf (Similarity: 0.28)
#  - italaw9383.pdf (Similarity: 0.28)
#  - ita0142.pdf (Similarity: 0.27)
#  - italaw7494_1.pdf (Similarity: 0.25)
#
# Top neighbors for ita0234_0.pdf:
#  - italaw1502.pdf (Similarity: 0.15)
#  - italaw3224.pdf (Similarity: 0.08)
#  - ita0333.pdf (Similarity: 0.07)
#  - italaw10925.pdf (Similarity: 0.07)
#  - italaw6278.pdf (Similarity: 0.07)
#
# Top neighbors for italaw16156.pdf:
#  - italaw16155.pdf (Similarity: 0.52)
#  - italaw181741.pdf (Similarity: 0.52)
#  - italaw16153.pdf (Similarity: 0.42)
#  - italaw16175.pdf (Similarity: 0.34)
#  - italaw9905_0.pdf (Similarity: 0.29)
#
# Top neighbors for ita0717.pdf:
#  - italaw1408.pdf (Similarity: 0.60)
#  - ita0530.pdf (Similarity: 0.41)
#  - ita0863.pdf (Similarity: 0.41)
#  - italaw4043.pdf (Similarity: 0.41)
#  - ita1073_0.pdf (Similarity: 0.39)
#
# Top neighbors for italaw181768.pdf:
#  - italaw181768_0.pdf (Similarity: 1.00)
#  - italaw16480.pdf (Similarity: 0.68)
#  - italaw16425_1.pdf (Similarity: 0.36)
#  - italaw182274.pdf (Similarity: 0.33)
#  - italaw171378.pdf (Similarity: 0.21)
#
# Top neighbors for italaw8039_0.pdf:
#  - italaw8039.pdf (Similarity: 1.00)
#  - italaw8042.pdf (Similarity: 0.80)
#  - italaw8038.pdf (Similarity: 0.79)
#  - italaw8044.pdf (Similarity: 0.78)
#  - ita0353_0.pdf (Similarity: 0.78)
#
# Top neighbors for ita0743.pdf:
#  - italaw16440.pdf (Similarity: 0.53)
#  - italaw171013.pdf (Similarity: 0.48)
#  - italaw4289.pdf (Similarity: 0.48)
#  - ita0696.pdf (Similarity: 0.47)
#  - ITA%20LAW%207009.pdf (Similarity: 0.45)
#
# Top neighbors for italaw11410.pdf:
#  - italaw170079.pdf (Similarity: 0.57)
#  - italaw3174_0.pdf (Similarity: 0.48)
#  - italaw4164.pdf (Similarity: 0.38)
#  - italaw10019.pdf (Similarity: 0.37)
#  - ita0907.pdf (Similarity: 0.35)
#
# Top neighbors for italaw11234_0.pdf:
#  - italaw9875.pdf (Similarity: 0.82)
#  - italaw11056.pdf (Similarity: 0.77)
#  - italaw16136.pdf (Similarity: 0.75)
#  - italaw11004.pdf (Similarity: 0.74)
#  - italaw16179.pdf (Similarity: 0.73)
#
# Top neighbors for italaw8415.pdf:
#  - italaw9532_0.pdf (Similarity: 1.00)
#  - italaw9531.pdf (Similarity: 1.00)
#  - italaw9530.pdf (Similarity: 1.00)
#  - italaw9529_0.pdf (Similarity: 1.00)
#  - italaw9528.pdf (Similarity: 1.00)
#
# Top neighbors for italaw11705.pdf:
#  - italaw11705_4.pdf (Similarity: 1.00)
#  - italaw11705_3.pdf (Similarity: 1.00)
#  - italaw11705_2.pdf (Similarity: 1.00)
#  - italaw11705_1.pdf (Similarity: 1.00)
#  - italaw11705_0.pdf (Similarity: 1.00)
#
# Top neighbors for italaw11508.pdf:
#  - italaw11925.pdf (Similarity: 0.69)
#  - italaw9843.pdf (Similarity: 0.68)
#  - italaw180832.pdf (Similarity: 0.61)
#  - italaw180838.pdf (Similarity: 0.56)
#  - italaw180834.pdf (Similarity: 0.50)
#
# Top neighbors for italaw9066.pdf:
#  - italaw9067.pdf (Similarity: 0.60)
#  - italaw9068.pdf (Similarity: 0.59)
#  - italaw9069.pdf (Similarity: 0.51)
#  - ita0473.pdf (Similarity: 0.49)
#  - ita0474.pdf (Similarity: 0.47)
#
# Top neighbors for italaw10271.pdf:
#  - italaw10263.pdf (Similarity: 0.93)
#  - italaw10267.pdf (Similarity: 0.89)
#  - italaw10269.pdf (Similarity: 0.86)
#  - italaw10265.pdf (Similarity: 0.86)
#  - 180727.pdf (Similarity: 0.54)
#
# Top neighbors for italaw16010.pdf:
#  - italaw16233.pdf (Similarity: 0.79)
#  - italaw16013.pdf (Similarity: 0.72)
#  - 180590.pdf (Similarity: 0.69)
#  - 180492.pdf (Similarity: 0.64)
#  - 180129.pdf (Similarity: 0.64)
#
# Top neighbors for italaw11482.pdf:
#  - 180091.pdf (Similarity: 0.92)
#  - italaw11485.pdf (Similarity: 0.91)
#  - italaw1587.pdf (Similarity: 0.87)
#  - italaw3213.pdf (Similarity: 0.87)
#  - italaw1201.pdf (Similarity: 0.86)
#
# Top neighbors for italaw7173.pdf:
#  - italaw4249.pdf (Similarity: 0.64)
#  - italaw171118.pdf (Similarity: 0.62)
#  - italaw10824.pdf (Similarity: 0.61)
#  - italaw10183.pdf (Similarity: 0.61)
#  - italaw10021.pdf (Similarity: 0.61)
#
# Top neighbors for italaw181328.pdf:
#  - 180691.pdf (Similarity: 0.51)
#  - 180692.pdf (Similarity: 0.47)
#  - italaw182314.pdf (Similarity: 0.39)
#  - italaw8836.pdf (Similarity: 0.38)
#  - italaw170099.pdf (Similarity: 0.37)
#
# Top neighbors for 180298.pdf:
#  - italaw170991_0.pdf (Similarity: 0.36)
#  - italaw170991.pdf (Similarity: 0.36)
#  - italaw170789.pdf (Similarity: 0.36)
#  - italaw16560_0.pdf (Similarity: 0.35)
#  - italaw16560.pdf (Similarity: 0.35)
#
# Top neighbors for italaw181979.pdf:
#  - italaw180907.pdf (Similarity: 0.27)
#  - italaw171355_0.pdf (Similarity: 0.16)
#  - italaw180908.pdf (Similarity: 0.14)
#  - italaw182455.pdf (Similarity: 0.13)
#  - 180621.pdf (Similarity: 0.12)
#
# Top neighbors for italaw1150.pdf:
#  - italaw1153_0.pdf (Similarity: 0.72)
#  - italaw1148.pdf (Similarity: 0.54)
#  - italaw1155.pdf (Similarity: 0.49)
#  - italaw7733_0.pdf (Similarity: 0.48)
#  - italaw1151.pdf (Similarity: 0.47)
#
# Top neighbors for italaw1148.pdf:
#  - italaw170837.pdf (Similarity: 0.71)
#  - italaw1510.pdf (Similarity: 0.69)
#  - italaw1313.pdf (Similarity: 0.69)
#  - italaw8455.pdf (Similarity: 0.68)
#  - italaw8316.pdf (Similarity: 0.68)
#
# Top neighbors for ita0882.pdf:
#  - italaw170970.pdf (Similarity: 0.17)
#  - 180775.pdf (Similarity: 0.14)
#  - ita0174_0.pdf (Similarity: 0.13)
#  - italaw1274.pdf (Similarity: 0.13)
#  - italaw9973.pdf (Similarity: 0.13)
#
# Top neighbors for italaw181910.pdf:
#  - italaw182287.pdf (Similarity: 0.51)
#  - italaw182145.pdf (Similarity: 0.50)
#  - 180672.pdf (Similarity: 0.48)
#  - italaw180890.pdf (Similarity: 0.47)
#  - italaw1576.pdf (Similarity: 0.46)
#
# Top neighbors for italaw8692.pdf:
#  - italaw8691_0.pdf (Similarity: 0.82)
#  - italaw8693.pdf (Similarity: 0.80)
#  - italaw8716.pdf (Similarity: 0.59)
#  - italaw8717.pdf (Similarity: 0.56)
#  - italaw8719.pdf (Similarity: 0.56)
#
# Top neighbors for 180273.pdf:
#  - 180161.pdf (Similarity: 0.87)
#  - 180162.pdf (Similarity: 0.82)
#  - 180484.pdf (Similarity: 0.20)
#  - italaw10183.pdf (Similarity: 0.18)
#  - italaw4250.pdf (Similarity: 0.18)
#
# Top neighbors for italaw11026_0.pdf:
#  - italaw11030.pdf (Similarity: 0.59)
#  - italaw4267.pdf (Similarity: 0.22)
#  - italaw4268.pdf (Similarity: 0.22)
#  - ita0449_0.pdf (Similarity: 0.20)
#  - italaw10361.pdf (Similarity: 0.20)
#
# Top neighbors for italaw11458.pdf:
#  - italaw10145_0.pdf (Similarity: 0.80)
#  - italaw10144.pdf (Similarity: 0.70)
#  - italaw10146.pdf (Similarity: 0.59)
#  - italaw9986.pdf (Similarity: 0.48)
#  - ita0022.pdf (Similarity: 0.42)
#
# Top neighbors for italaw7382.pdf:
#  - italaw9951.pdf (Similarity: 0.51)
#  - italaw170482.pdf (Similarity: 0.49)
#  - italaw4400.pdf (Similarity: 0.43)
#  - ITA%20LAW%207001.pdf (Similarity: 0.42)
#  - italaw7385.pdf (Similarity: 0.40)
#
# Top neighbors for italaw181027.pdf:
#  - italaw16216.pdf (Similarity: 0.60)
#  - italaw11514.pdf (Similarity: 0.56)
#  - italaw181029.pdf (Similarity: 0.52)
#  - italaw11651.pdf (Similarity: 0.48)
#  - italaw11194.pdf (Similarity: 0.46)
#
# Top neighbors for ita0626.pdf:
#  - italaw4003.pdf (Similarity: 0.72)
#  - ita0623.pdf (Similarity: 0.60)
#  - italaw10860.pdf (Similarity: 0.52)
#  - italaw7998_0.pdf (Similarity: 0.51)
#  - italaw16204.pdf (Similarity: 0.49)
#
# Top neighbors for italaw180858.pdf:
#  - italaw16080.pdf (Similarity: 0.81)
#  - italaw16053.pdf (Similarity: 0.80)
#  - italaw16109.pdf (Similarity: 0.72)
#  - italaw16087.pdf (Similarity: 0.71)
#  - italaw16111.pdf (Similarity: 0.66)
#
# Top neighbors for ita0614.pdf:
#  - ita0815.pdf (Similarity: 0.63)
#  - ita0803.pdf (Similarity: 0.61)
#  - italaw7337.pdf (Similarity: 0.55)
#  - ita0823.pdf (Similarity: 0.51)
#  - italaw10634.pdf (Similarity: 0.47)
#
# Top neighbors for italaw180928.pdf:
#  - italaw180929.pdf (Similarity: 0.99)
#  - italaw10287.pdf (Similarity: 0.60)
#  - italaw10184.pdf (Similarity: 0.58)
#  - italaw10286.pdf (Similarity: 0.58)
#  - italaw9707.pdf (Similarity: 0.56)
#
# Top neighbors for ita0596.pdf:
#  - ita1061.pdf (Similarity: 0.81)
#  - ita0997.pdf (Similarity: 0.80)
#  - italaw1473.pdf (Similarity: 0.73)
#  - ita0703.pdf (Similarity: 0.73)
#  - italaw10651.pdf (Similarity: 0.51)
#
# Top neighbors for italaw7335.pdf:
#  - italaw7332.pdf (Similarity: 0.76)
#  - italaw7330.pdf (Similarity: 0.67)
#  - italaw7333.pdf (Similarity: 0.64)
#  - italaw7329.pdf (Similarity: 0.60)
#  - italaw7331.pdf (Similarity: 0.56)
#
# Top neighbors for ita0296.pdf:
#  - ita0230.pdf (Similarity: 0.84)
#  - ita0063.pdf (Similarity: 0.83)
#  - ita0772.pdf (Similarity: 0.83)
#  - ita0298.pdf (Similarity: 0.78)
#  - ita0217.pdf (Similarity: 0.77)
#
# Top neighbors for italaw8509.pdf:
#  - italaw9532_0.pdf (Similarity: 1.00)
#  - italaw9531.pdf (Similarity: 1.00)
#  - italaw9530.pdf (Similarity: 1.00)
#  - italaw9529_0.pdf (Similarity: 1.00)
#  - italaw9528.pdf (Similarity: 1.00)
#
# Top neighbors for italaw4408_Part6.pdf:
#  - italaw4408_Part4.pdf (Similarity: 0.41)
#  - ita1064.pdf (Similarity: 0.36)
#  - italaw4408_Part8.pdf (Similarity: 0.33)
#  - italaw170356.pdf (Similarity: 0.31)
#  - italaw16406.pdf (Similarity: 0.31)
#
# Top neighbors for italaw8883_0.pdf:
#  - italaw8881.pdf (Similarity: 0.78)
#  - italaw8884.pdf (Similarity: 0.69)
#  - italaw8909_0.pdf (Similarity: 0.67)
#  - ita0384.pdf (Similarity: 0.66)
#  - ita0381.pdf (Similarity: 0.64)
#
# Top neighbors for italaw1263.pdf:
#  - italaw1264.pdf (Similarity: 0.75)
#  - italaw1265.pdf (Similarity: 0.69)
#  - ita1051.pdf (Similarity: 0.48)
#  - ita0701.pdf (Similarity: 0.44)
#  - italaw7611.pdf (Similarity: 0.43)
#
# Top neighbors for italaw1188.pdf:
#  - italaw1189.pdf (Similarity: 0.84)
#  - ita0202.pdf (Similarity: 0.75)
#  - ita0194.pdf (Similarity: 0.66)
#  - italaw1187.pdf (Similarity: 0.64)
#  - ita0195.pdf (Similarity: 0.61)
#
# Top neighbors for italaw10991.pdf:
#  - italaw10997.pdf (Similarity: 0.65)
#  - italaw10980_0.pdf (Similarity: 0.62)
#  - italaw10973_0.pdf (Similarity: 0.61)
#  - italaw10972.pdf (Similarity: 0.58)
#  - italaw9739.pdf (Similarity: 0.56)
#
# Top neighbors for italaw181037.pdf:
#  - italaw181754.pdf (Similarity: 0.45)
#  - italaw170888.pdf (Similarity: 0.43)
#  - italaw20000_0.pdf (Similarity: 0.38)
#  - italaw10139.pdf (Similarity: 0.37)
#  - italaw10500.pdf (Similarity: 0.35)
#
# Top neighbors for ita1077.pdf:
#  - ita0446.pdf (Similarity: 0.20)
#  - ita0348.pdf (Similarity: 0.20)
#  - ita0444.pdf (Similarity: 0.18)
#  - italaw1185.pdf (Similarity: 0.17)
#  - ita0445.pdf (Similarity: 0.17)
#
# Top neighbors for italaw170254.pdf:
#  - italaw170230.pdf (Similarity: 0.13)
#  - italaw171189.pdf (Similarity: 0.10)
#  - italaw16266.pdf (Similarity: 0.10)
#  - italaw16208.pdf (Similarity: 0.09)
#  - italaw11431.pdf (Similarity: 0.08)
#
# Top neighbors for ita0191_0.pdf:
#  - ita0192_0.pdf (Similarity: 0.84)
#  - italaw1188.pdf (Similarity: 0.50)
#  - ita0202.pdf (Similarity: 0.43)
#  - italaw1189.pdf (Similarity: 0.41)
#  - italaw1187.pdf (Similarity: 0.30)
#
# Top neighbors for italaw1216.pdf:
#  - italaw11744.pdf (Similarity: 0.52)
#  - italaw16049.pdf (Similarity: 0.52)
#  - italaw10431.pdf (Similarity: 0.52)
#  - italaw170583.pdf (Similarity: 0.48)
#  - italaw11923.pdf (Similarity: 0.46)
#
# Top neighbors for italaw10213.pdf:
#  - italaw10594_0.pdf (Similarity: 0.83)
#  - italaw10817.pdf (Similarity: 0.68)
#  - italaw11086.pdf (Similarity: 0.64)
#  - italaw9618.pdf (Similarity: 0.49)
#  - ita0420.pdf (Similarity: 0.44)
#
# Top neighbors for italaw10651.pdf:
#  - italaw3160.pdf (Similarity: 0.70)
#  - ita1061.pdf (Similarity: 0.60)
#  - ita0596.pdf (Similarity: 0.51)
#  - ita0997.pdf (Similarity: 0.50)
#  - ita0961.pdf (Similarity: 0.49)
#
# Top neighbors for italaw170068.pdf:
#  - italaw10671.pdf (Similarity: 0.30)
#  - italaw4227.pdf (Similarity: 0.29)
#  - italaw10678.pdf (Similarity: 0.29)
#  - italaw10668.pdf (Similarity: 0.29)
#  - italaw10674.pdf (Similarity: 0.29)
#
# Top neighbors for italaw9264.pdf:
#  - italaw9265.pdf (Similarity: 1.00)
#  - italaw9622.pdf (Similarity: 0.86)
#  - italaw9041.pdf (Similarity: 0.85)
#  - italaw9760_0.pdf (Similarity: 0.85)
#  - italaw8487_0.pdf (Similarity: 0.78)
#
# Top neighbors for italaw10220.pdf:
#  - italaw10223.pdf (Similarity: 0.34)
#  - italaw8946.pdf (Similarity: 0.32)
#  - italaw10224.pdf (Similarity: 0.32)
#  - italaw3159.pdf (Similarity: 0.30)
#  - italaw4160.pdf (Similarity: 0.29)
#
# Top neighbors for italaw8350.pdf:
#  - italaw8346.pdf (Similarity: 0.93)
#  - italaw9532_0.pdf (Similarity: 0.81)
#  - italaw9531.pdf (Similarity: 0.81)
#  - italaw9530.pdf (Similarity: 0.81)
#  - italaw9529_0.pdf (Similarity: 0.81)
#
# Top neighbors for italaw11865.pdf:
#  - italaw11618.pdf (Similarity: 1.00)
#  - italaw11459.pdf (Similarity: 0.83)
#  - italaw11626.pdf (Similarity: 0.70)
#  - italaw11104.pdf (Similarity: 0.68)
#  - italaw11273.pdf (Similarity: 0.68)
#
# Top neighbors for italaw4381.pdf:
#  - italaw4378.pdf (Similarity: 0.67)
#  - italaw4137.pdf (Similarity: 0.67)
#  - italaw4046.pdf (Similarity: 0.66)
#  - italaw4384.pdf (Similarity: 0.65)
#  - italaw7465.pdf (Similarity: 0.64)
#
# Top neighbors for ita0174_0.pdf:
#  - italaw1274.pdf (Similarity: 0.59)
#  - ita0167.pdf (Similarity: 0.47)
#  - ita0160.pdf (Similarity: 0.45)
#  - italaw9372.pdf (Similarity: 0.41)
#  - italaw11001.pdf (Similarity: 0.36)
#
# Top neighbors for italaw182477.pdf:
#  - italaw170317.pdf (Similarity: 0.70)
#  - italaw11518.pdf (Similarity: 0.58)
#  - italaw182348.pdf (Similarity: 0.54)
#  - italaw16534.pdf (Similarity: 0.53)
#  - italaw181200.pdf (Similarity: 0.50)
#
# Top neighbors for italaw171266.pdf:
#  - italaw170142.pdf (Similarity: 0.47)
#  - italaw180890.pdf (Similarity: 0.43)
#  - 180634.pdf (Similarity: 0.43)
#  - 180268.pdf (Similarity: 0.42)
#  - italaw181910.pdf (Similarity: 0.41)
#
# Top neighbors for italaw4202.pdf:
#  - italaw4200.pdf (Similarity: 0.66)
#  - italaw4204.pdf (Similarity: 0.53)
#  - italaw8954.pdf (Similarity: 0.49)
#  - italaw7692_0.pdf (Similarity: 0.49)
#  - italaw4197.pdf (Similarity: 0.46)
#
# Top neighbors for italaw10679.pdf:
#  - italaw16427_1.pdf (Similarity: 0.40)
#  - italaw7429.pdf (Similarity: 0.40)
#  - italaw182596.pdf (Similarity: 0.40)
#  - italaw10817.pdf (Similarity: 0.39)
#  - italaw7303_0.pdf (Similarity: 0.39)
#
# Top neighbors for ita0517_0.pdf:
#  - ita0883.pdf (Similarity: 0.64)
#  - italaw8565.pdf (Similarity: 0.63)
#  - italaw9100.pdf (Similarity: 0.60)
#  - ita0803.pdf (Similarity: 0.51)
#  - ita0815.pdf (Similarity: 0.50)
#
# Top neighbors for italaw8096_3.pdf:
#  - italaw8097_0.pdf (Similarity: 0.54)
#  - italaw10134_0.pdf (Similarity: 0.51)
#  - italaw10230.pdf (Similarity: 0.39)
#  - italaw170825.pdf (Similarity: 0.25)
#  - 180193.pdf (Similarity: 0.24)
#
# Top neighbors for 180357.pdf:
#  - 180355.pdf (Similarity: 0.87)
#  - 180356.pdf (Similarity: 0.87)
#  - 180359.pdf (Similarity: 0.83)
#  - 180354.pdf (Similarity: 0.78)
#  - italaw170912.pdf (Similarity: 0.77)
#
# Top neighbors for ita0470.pdf:
#  - italaw9047_0.pdf (Similarity: 0.87)
#  - italaw9049.pdf (Similarity: 0.83)
#  - italaw9048.pdf (Similarity: 0.80)
#  - italaw9045.pdf (Similarity: 0.79)
#  - italaw4030.pdf (Similarity: 0.60)
#
# Top neighbors for italaw9124.pdf:
#  - italaw9124_0.pdf (Similarity: 1.00)
#  - italaw9126.pdf (Similarity: 0.55)
#  - italaw8603.pdf (Similarity: 0.53)
#  - italaw11902.pdf (Similarity: 0.52)
#  - italaw181491.pdf (Similarity: 0.52)
#
# Top neighbors for italaw7061.pdf:
#  - italaw7056.pdf (Similarity: 0.51)
#  - italaw7053.pdf (Similarity: 0.42)
#  - italaw1262.pdf (Similarity: 0.35)
#  - italaw7055.pdf (Similarity: 0.35)
#  - 180092.pdf (Similarity: 0.33)
#
# Top neighbors for italaw8559.pdf:
#  - italaw8286_0.pdf (Similarity: 0.36)
#  - italaw10244.pdf (Similarity: 0.20)
#  - ita0268_0.pdf (Similarity: 0.19)
#  - italaw4388.pdf (Similarity: 0.19)
#  - ita0531.pdf (Similarity: 0.19)
#
# Top neighbors for ita0055.pdf:
#  - ita0826.pdf (Similarity: 1.00)
#  - ita0813.pdf (Similarity: 0.64)
#  - italaw4365.pdf (Similarity: 0.62)
#  - italaw6304.pdf (Similarity: 0.62)
#  - ita0819.pdf (Similarity: 0.59)
#
# Top neighbors for italaw16485.pdf:
#  - italaw9201_1.pdf (Similarity: 0.52)
#  - italaw9203.pdf (Similarity: 0.50)
#  - italaw10704.pdf (Similarity: 0.48)
#  - italaw9206.pdf (Similarity: 0.48)
#  - italaw8781.pdf (Similarity: 0.48)
#
# Top neighbors for italaw16571.pdf:
#  - italaw170047.pdf (Similarity: 0.98)
#  - italaw7440.pdf (Similarity: 0.08)
#  - italaw1270.pdf (Similarity: 0.08)
#  - italaw1269.pdf (Similarity: 0.07)
#  - italaw10243_0.pdf (Similarity: 0.07)
#
# Top neighbors for italaw10905.pdf:
#  - italaw10546.pdf (Similarity: 0.64)
#  - italaw11586.pdf (Similarity: 0.49)
#  - italaw171417.pdf (Similarity: 0.43)
#  - italaw10118.pdf (Similarity: 0.40)
#  - italaw16491.pdf (Similarity: 0.40)
#
# Top neighbors for italaw1185.pdf:
#  - italaw8836.pdf (Similarity: 0.56)
#  - italaw4484.pdf (Similarity: 0.51)
#  - italaw4176.pdf (Similarity: 0.47)
#  - italaw171173.pdf (Similarity: 0.46)
#  - italaw181029.pdf (Similarity: 0.45)
#
# Top neighbors for italaw9108.pdf:
#  - italaw9109.pdf (Similarity: 0.77)
#  - italaw9107.pdf (Similarity: 0.60)
#  - italaw9118.pdf (Similarity: 0.59)
#  - italaw9115.pdf (Similarity: 0.55)
#  - italaw9123.pdf (Similarity: 0.52)
#
# Top neighbors for 180596.pdf:
#  - 180597.pdf (Similarity: 0.90)
#  - italaw182574.pdf (Similarity: 0.86)
#  - 180593.pdf (Similarity: 0.86)
#  - 180595.pdf (Similarity: 0.85)
#  - italaw182573.pdf (Similarity: 0.81)
#
# Top neighbors for italaw8790.pdf:
#  - italaw9350.pdf (Similarity: 0.86)
#  - italaw9953.pdf (Similarity: 0.86)
#  - italaw7378.pdf (Similarity: 0.78)
#  - italaw7375.pdf (Similarity: 0.76)
#  - italaw7387.pdf (Similarity: 0.75)
#
# Top neighbors for italaw171044.pdf:
#  - italaw10738.pdf (Similarity: 0.41)
#  - italaw1182.pdf (Similarity: 0.41)
#  - italaw10737.pdf (Similarity: 0.22)
#  - italaw11880.pdf (Similarity: 0.21)
#  - italaw170883.pdf (Similarity: 0.20)
#
# Top neighbors for italaw7139.pdf:
#  - italaw7129.pdf (Similarity: 1.00)
#  - italaw7137.pdf (Similarity: 0.44)
#  - italaw7127.pdf (Similarity: 0.44)
#  - italaw7095_0.pdf (Similarity: 0.44)
#  - italaw7120.pdf (Similarity: 0.44)
#
# Top neighbors for italaw180818.pdf:
#  - italaw11213.pdf (Similarity: 0.63)
#  - italaw182386.pdf (Similarity: 0.63)
#  - italaw182385.pdf (Similarity: 0.63)
#  - italaw10512.pdf (Similarity: 0.60)
#  - italaw182201.pdf (Similarity: 0.58)
#
# Top neighbors for italaw16422.pdf:
#  - italaw16001.pdf (Similarity: 0.74)
#  - italaw182566.pdf (Similarity: 0.72)
#  - italaw170942.pdf (Similarity: 0.72)
#  - italaw16293.pdf (Similarity: 0.66)
#  - italaw170940.pdf (Similarity: 0.64)
#
# Top neighbors for ita0325.pdf:
#  - ita0319.pdf (Similarity: 0.01)
#  - ita0327.pdf (Similarity: 0.01)
#  - 18025.pdf (Similarity: 0.01)
#  - italaw7199.pdf (Similarity: 0.01)
#  - ita0596.pdf (Similarity: 0.01)
#
# Top neighbors for italaw11777.pdf:
#  - italaw11778.pdf (Similarity: 0.88)
#  - italaw170666.pdf (Similarity: 0.79)
#  - italaw170641.pdf (Similarity: 0.79)
#  - italaw16007.pdf (Similarity: 0.75)
#  - 180582.pdf (Similarity: 0.75)
#
# Top neighbors for italaw182540.pdf:
#  - italaw182537.pdf (Similarity: 0.88)
#  - italaw182539.pdf (Similarity: 0.82)
#  - italaw182536.pdf (Similarity: 0.68)
#  - italaw182533.pdf (Similarity: 0.54)
#  - italaw170802.pdf (Similarity: 0.48)
#
# Top neighbors for italaw1477.pdf:
#  - italaw1475.pdf (Similarity: 0.71)
#  - italaw1471.pdf (Similarity: 0.61)
#  - italaw1476.pdf (Similarity: 0.50)
#  - ita0704.pdf (Similarity: 0.47)
#  - italaw1472.pdf (Similarity: 0.40)
#
# Top neighbors for italaw8947.pdf:
#  - italaw4305.pdf (Similarity: 0.56)
#  - ita0727.pdf (Similarity: 0.56)
#  - ita0928.pdf (Similarity: 0.55)
#  - 180648.pdf (Similarity: 0.51)
#  - italaw6274.pdf (Similarity: 0.50)
#
# Top neighbors for italaw181806.pdf:
#  - italaw180933.pdf (Similarity: 0.57)
#  - 180092.pdf (Similarity: 0.57)
#  - italaw170134.pdf (Similarity: 0.55)
#  - italaw182391.pdf (Similarity: 0.54)
#  - italaw10632.pdf (Similarity: 0.53)
#
# Top neighbors for italaw6351.pdf:
#  - ita0864.pdf (Similarity: 0.36)
#  - ita0863.pdf (Similarity: 0.35)
#  - italaw8769.pdf (Similarity: 0.29)
#  - italaw170744.pdf (Similarity: 0.28)
#  - italaw9383.pdf (Similarity: 0.25)
#
# Top neighbors for italaw9045.pdf:
#  - italaw9047_0.pdf (Similarity: 0.82)
#  - italaw9048.pdf (Similarity: 0.81)
#  - ita0470.pdf (Similarity: 0.79)
#  - italaw9049.pdf (Similarity: 0.71)
#  - ita0971.pdf (Similarity: 0.55)
#
# Top neighbors for italaw10866.pdf:
#  - italaw10307.pdf (Similarity: 0.38)
#  - italaw11391.pdf (Similarity: 0.30)
#  - italaw10863.pdf (Similarity: 0.28)
#  - italaw1089.pdf (Similarity: 0.27)
#  - italaw9225.pdf (Similarity: 0.27)
#
# Top neighbors for italaw11662.pdf:
#  - italaw11536.pdf (Similarity: 0.62)
#  - italaw11392.pdf (Similarity: 0.59)
#  - italaw11243.pdf (Similarity: 0.55)
#  - italaw16133.pdf (Similarity: 0.54)
#  - italaw11676.pdf (Similarity: 0.50)
#
# Top neighbors for italaw7823.pdf:
#  - ita0330_0.pdf (Similarity: 0.35)
#  - italaw11626.pdf (Similarity: 0.21)
#  - italaw11104.pdf (Similarity: 0.19)
#  - italaw11273.pdf (Similarity: 0.19)
#  - italaw16325.pdf (Similarity: 0.17)
#
# Top neighbors for italaw16321.pdf:
#  - italaw11563.pdf (Similarity: 0.58)
#  - italaw11923.pdf (Similarity: 0.58)
#  - italaw182024.pdf (Similarity: 0.46)
#  - italaw16049.pdf (Similarity: 0.42)
#  - italaw16002.pdf (Similarity: 0.41)
#
# Top neighbors for italaw9756.pdf:
#  - italaw7410.pdf (Similarity: 0.47)
#  - italaw181952_0.pdf (Similarity: 0.44)
#  - italaw4219.pdf (Similarity: 0.38)
#  - ita0449_0.pdf (Similarity: 0.34)
#  - italaw9400.pdf (Similarity: 0.29)
#
# Top neighbors for italaw170575.pdf:
#  - italaw170581.pdf (Similarity: 0.81)
#  - italaw170578.pdf (Similarity: 0.76)
#  - italaw180865.pdf (Similarity: 0.75)
#  - italaw180861.pdf (Similarity: 0.71)
#  - italaw180863.pdf (Similarity: 0.60)
#
# Top neighbors for italaw9659.pdf:
#  - italaw4166.pdf (Similarity: 0.90)
#  - italaw4344.pdf (Similarity: 0.87)
#  - italaw9651_0.pdf (Similarity: 0.87)
#  - italaw3188.pdf (Similarity: 0.85)
#  - italaw4010.pdf (Similarity: 0.84)
#
# Top neighbors for italaw4223.pdf:
#  - italaw4222.pdf (Similarity: 0.48)
#  - italaw1585.pdf (Similarity: 0.25)
#  - italaw9934.pdf (Similarity: 0.25)
#  - italaw1426.pdf (Similarity: 0.24)
#  - ita0175.pdf (Similarity: 0.22)
#
# Top neighbors for italaw8015.pdf:
#  - italaw16216.pdf (Similarity: 0.55)
#  - italaw3162.pdf.pdf (Similarity: 0.53)
#  - italaw9964.pdf (Similarity: 0.51)
#  - italaw10508.pdf (Similarity: 0.50)
#  - ita0240.pdf (Similarity: 0.50)
#
# Top neighbors for italaw10240.pdf:
#  - italaw10240_0.pdf (Similarity: 1.00)
#  - italaw10238.pdf (Similarity: 0.78)
#  - italaw10239.pdf (Similarity: 0.66)
#  - italaw10237.pdf (Similarity: 0.61)
#  - italaw9292.pdf (Similarity: 0.33)
#
# Top neighbors for italaw10087.pdf:
#  - italaw10718_0.pdf (Similarity: 0.57)
#  - italaw10085.pdf (Similarity: 0.56)
#  - italaw10086_0.pdf (Similarity: 0.54)
#  - 180717.pdf (Similarity: 0.52)
#  - 180164.pdf (Similarity: 0.46)
#
# Top neighbors for 180657.pdf:
#  - 180175.pdf (Similarity: 0.57)
#  - italaw11923.pdf (Similarity: 0.43)
#  - 180786.pdf (Similarity: 0.41)
#  - 180376.pdf (Similarity: 0.40)
#  - italaw182061.pdf (Similarity: 0.40)
#
# Top neighbors for italaw182206.pdf:
#  - italaw11150.pdf (Similarity: 0.43)
#  - italaw16527.pdf (Similarity: 0.43)
#  - italaw182205.pdf (Similarity: 0.40)
#  - italaw10180.pdf (Similarity: 0.40)
#  - italaw16563_0.pdf (Similarity: 0.37)
#
# Top neighbors for italaw4394.pdf:
#  - italaw4396.pdf (Similarity: 0.84)
#  - italaw4398.pdf (Similarity: 0.83)
#  - italaw7434.pdf (Similarity: 0.81)
#  - italaw7583.pdf (Similarity: 0.77)
#  - italaw6365.pdf (Similarity: 0.72)
#
# Top neighbors for italaw9096.pdf:
#  - italaw9148.pdf (Similarity: 0.69)
#  - italaw9099.pdf (Similarity: 0.65)
#  - italaw9150.pdf (Similarity: 0.59)
#  - ita0090.pdf (Similarity: 0.47)
#  - italaw9098_1.pdf (Similarity: 0.46)
#
# Top neighbors for ita0033.pdf:
#  - italaw1320.pdf (Similarity: 0.86)
#  - italaw3109.pdf (Similarity: 0.51)
#  - italaw3001.pdf (Similarity: 0.49)
#  - italaw3111.pdf (Similarity: 0.46)
#  - italaw10634.pdf (Similarity: 0.45)
#
# Top neighbors for italaw9198.pdf:
#  - italaw7096.pdf (Similarity: 1.00)
#  - italaw8133_6.pdf (Similarity: 0.61)
#  - italaw11503.pdf (Similarity: 0.56)
#  - italaw180911.pdf (Similarity: 0.55)
#  - italaw10464_0.pdf (Similarity: 0.53)
#
# Top neighbors for italaw10544_1.pdf:
#  - italaw170682.pdf (Similarity: 0.43)
#  - italaw10546.pdf (Similarity: 0.36)
#  - italaw10905.pdf (Similarity: 0.35)
#  - italaw10409.pdf (Similarity: 0.35)
#  - italaw10379.pdf (Similarity: 0.33)
#
# Top neighbors for italaw8024.pdf:
#  - italaw3057.pdf (Similarity: 0.44)
#  - italaw16362.pdf (Similarity: 0.37)
#  - italaw4289.pdf (Similarity: 0.36)
#  - ita0313.pdf (Similarity: 0.36)
#  - italaw1306_0.pdf (Similarity: 0.36)
#
# Top neighbors for italaw8922.pdf:
#  - italaw8921.pdf (Similarity: 1.00)
#  - italaw8920.pdf (Similarity: 0.86)
#  - italaw8926_0.pdf (Similarity: 0.83)
#  - italaw8924.pdf (Similarity: 0.82)
#  - italaw8923.pdf (Similarity: 0.77)
#
# Top neighbors for ita0362.pdf:
#  - italaw1257.pdf (Similarity: 0.52)
#  - italaw11704.pdf (Similarity: 0.51)
#  - italaw11796.pdf (Similarity: 0.49)
#  - italaw16193.pdf (Similarity: 0.49)
#  - italaw11946.pdf (Similarity: 0.49)
#
# Top neighbors for italaw1394.pdf:
#  - italaw1393.pdf (Similarity: 0.49)
#  - ita0914.pdf (Similarity: 0.36)
#  - italaw1389.pdf (Similarity: 0.33)
#  - italaw3277.pdf (Similarity: 0.32)
#  - italaw7393.pdf (Similarity: 0.30)
#
# Top neighbors for 180696.pdf:
#  - 180695.pdf (Similarity: 0.60)
#  - 180362.pdf (Similarity: 0.58)
#  - italaw181495.pdf (Similarity: 0.53)
#  - 180361.pdf (Similarity: 0.45)
#  - italaw7074.pdf (Similarity: 0.37)
#
# Top neighbors for italaw170735.pdf:
#  - 180092.pdf (Similarity: 0.56)
#  - italaw10632.pdf (Similarity: 0.56)
#  - italaw11707.pdf (Similarity: 0.56)
#  - italaw180933.pdf (Similarity: 0.55)
#  - italaw170134.pdf (Similarity: 0.55)
#
# Top neighbors for italaw4386.pdf:
#  - italaw4138.pdf (Similarity: 0.72)
#  - italaw1172.pdf (Similarity: 0.69)
#  - italaw1530.pdf (Similarity: 0.69)
#  - ITA%20LAW%207021.pdf (Similarity: 0.68)
#  - italaw4131.pdf (Similarity: 0.68)
#
# Top neighbors for italaw180887.pdf:
#  - italaw180883.pdf (Similarity: 0.85)
#  - italaw180884.pdf (Similarity: 0.70)
#  - italaw180886.pdf (Similarity: 0.66)
#  - italaw180885.pdf (Similarity: 0.64)
#  - italaw9815.pdf (Similarity: 0.48)
#
# Top neighbors for italaw1090_0.pdf:
#  - italaw11333_0.pdf (Similarity: 0.36)
#  - italaw7462.pdf (Similarity: 0.23)
#  - italaw11047.pdf (Similarity: 0.21)
#  - italaw11042_0.pdf (Similarity: 0.21)
#  - italaw11037.pdf (Similarity: 0.21)
#
# Top neighbors for italaw8402.pdf:
#  - italaw9532_0.pdf (Similarity: 1.00)
#  - italaw9531.pdf (Similarity: 1.00)
#  - italaw9530.pdf (Similarity: 1.00)
#  - italaw9529_0.pdf (Similarity: 1.00)
#  - italaw9528.pdf (Similarity: 1.00)
#
# Top neighbors for italaw181166.pdf:
#  - italaw9970_1.pdf (Similarity: 0.45)
#  - italaw170189_0.pdf (Similarity: 0.38)
#  - italaw170191_0.pdf (Similarity: 0.37)
#  - italaw170190_0.pdf (Similarity: 0.36)
#  - italaw170187_0.pdf (Similarity: 0.34)
#
# Top neighbors for italaw4462.pdf:
#  - italaw11137.pdf (Similarity: 0.59)
#  - italaw8485.pdf (Similarity: 0.45)
#  - italaw8480.pdf (Similarity: 0.31)
#  - italaw7064.pdf (Similarity: 0.29)
#  - ita0981.pdf (Similarity: 0.27)
#
# Top neighbors for ita0910.pdf:
#  - ita0411.pdf (Similarity: 1.00)
#  - ita0891.pdf (Similarity: 0.93)
#  - italaw4158_0.pdf (Similarity: 0.67)
#  - italaw7258.pdf (Similarity: 0.62)
#  - italaw7255.pdf (Similarity: 0.62)
#
# Top neighbors for italaw9509.pdf:
#  - italaw9508.pdf (Similarity: 0.72)
#  - italaw9506.pdf (Similarity: 0.49)
#  - 18023.pdf (Similarity: 0.44)
#  - italaw11742.pdf (Similarity: 0.43)
#  - italaw8198_0.pdf (Similarity: 0.42)
#
# Top neighbors for italaw171408_0.pdf:
#  - italaw171408.pdf (Similarity: 1.00)
#  - italaw182020.pdf (Similarity: 0.66)
#  - italaw170749.pdf (Similarity: 0.65)
#  - italaw170754.pdf (Similarity: 0.61)
#  - italaw170752.pdf (Similarity: 0.45)
#
# Top neighbors for ita0074.pdf:
#  - ita0075.pdf (Similarity: 0.93)
#  - ita0422.pdf (Similarity: 0.36)
#  - ita0779.pdf (Similarity: 0.35)
#  - ita0778.pdf (Similarity: 0.33)
#  - ita0439.pdf (Similarity: 0.31)
#
# Top neighbors for italaw4448.pdf:
#  - italaw1094.pdf (Similarity: 0.80)
#  - italaw1096.pdf (Similarity: 0.71)
#  - ita0577.pdf (Similarity: 0.60)
#  - ita0574.pdf (Similarity: 0.53)
#  - ita0571.pdf (Similarity: 0.49)
#
# Top neighbors for italaw7160.pdf:
#  - italaw6210_0.pdf (Similarity: 0.55)
#  - ITA%20LAW%207026.pdf (Similarity: 0.54)
#  - italaw1145.pdf (Similarity: 0.54)
#  - italaw1146_0.pdf (Similarity: 0.49)
#  - italaw6213.pdf (Similarity: 0.42)
#
# Top neighbors for italaw8319.pdf:
#  - italaw8302_0.pdf (Similarity: 0.71)
#  - italaw16082.pdf (Similarity: 0.19)
#  - italaw16072.pdf (Similarity: 0.15)
#  - italaw10658.pdf (Similarity: 0.14)
#  - italaw1156.pdf (Similarity: 0.14)
#
# Top neighbors for italaw7302.pdf:
#  - italaw4351.pdf (Similarity: 0.51)
#  - italaw8028_0.pdf (Similarity: 0.45)
#  - italaw1312.pdf (Similarity: 0.43)
#  - italaw6272_0.pdf (Similarity: 0.43)
#  - italaw4329.pdf (Similarity: 0.42)
#
# Top neighbors for 180446.pdf:
#  - 180445.pdf (Similarity: 0.47)
#  - italaw7344.pdf (Similarity: 0.42)
#  - italaw6322_0.pdf (Similarity: 0.42)
#  - italaw6345.pdf (Similarity: 0.40)
#  - ita0497.pdf (Similarity: 0.35)
#
# Top neighbors for 180455.pdf:
#  - 180457.pdf (Similarity: 1.00)
#  - 180417.pdf (Similarity: 1.00)
#  - italaw170991_0.pdf (Similarity: 0.52)
#  - italaw170991.pdf (Similarity: 0.52)
#  - italaw170789.pdf (Similarity: 0.52)
#
# Top neighbors for italaw8681.pdf:
#  - italaw8681_0.pdf (Similarity: 1.00)
#  - italaw8682.pdf (Similarity: 0.81)
#  - italaw8684.pdf (Similarity: 0.60)
#  - italaw8680.pdf (Similarity: 0.55)
#  - italaw8683.pdf (Similarity: 0.54)
#
# Top neighbors for italaw171003.pdf:
#  - italaw171005.pdf (Similarity: 0.60)
#  - italaw171002.pdf (Similarity: 0.57)
#  - italaw171004.pdf (Similarity: 0.54)
#  - ita0872.pdf (Similarity: 0.19)
#  - ita0268_0.pdf (Similarity: 0.15)
#
# Top neighbors for italaw170504.pdf:
#  - italaw170503.pdf (Similarity: 0.85)
#  - italaw170505.pdf (Similarity: 0.76)
#  - italaw170502.pdf (Similarity: 0.76)
#  - italaw170498.pdf (Similarity: 0.74)
#  - italaw170501.pdf (Similarity: 0.68)
#
# Top neighbors for italaw10115.pdf:
#  - italaw9263.pdf (Similarity: 0.78)
#  - italaw8213_1.pdf (Similarity: 0.51)
#  - italaw10451.pdf (Similarity: 0.21)
#  - italaw8785.pdf (Similarity: 0.19)
#  - italaw182051.pdf (Similarity: 0.19)
#
# Top neighbors for italaw1146_0.pdf:
#  - ITA%20LAW%207026.pdf (Similarity: 0.62)
#  - italaw1145.pdf (Similarity: 0.61)
#  - italaw6210_0.pdf (Similarity: 0.60)
#  - italaw7160.pdf (Similarity: 0.49)
#  - italaw9769_1.pdf (Similarity: 0.29)
#
# Top neighbors for 180422.pdf:
#  - italaw180903.pdf (Similarity: 0.52)
#  - italaw10143_0_0.pdf (Similarity: 0.29)
#  - italaw170892.pdf (Similarity: 0.28)
#  - italaw11597.pdf (Similarity: 0.27)
#  - italaw170449.pdf (Similarity: 0.26)
#
# Top neighbors for italaw7046.pdf:
#  - italaw7526.pdf (Similarity: 0.67)
#  - italaw4384.pdf (Similarity: 0.64)
#  - italaw7263.pdf (Similarity: 0.62)
#  - italaw7465.pdf (Similarity: 0.62)
#  - italaw1582.pdf (Similarity: 0.61)
#
# Top neighbors for italaw11386.pdf:
#  - italaw16315.pdf (Similarity: 0.57)
#  - italaw16049.pdf (Similarity: 0.51)
#  - italaw11744.pdf (Similarity: 0.51)
#  - italaw16195.pdf (Similarity: 0.48)
#  - italaw170583.pdf (Similarity: 0.47)
#
# Top neighbors for ita0696.pdf:
#  - italaw171173.pdf (Similarity: 0.52)
#  - ITA%20LAW%207009.pdf (Similarity: 0.48)
#  - 180612.pdf (Similarity: 0.48)
#  - italaw181029.pdf (Similarity: 0.47)
#  - ita0743.pdf (Similarity: 0.47)
#
# Top neighbors for italaw11081.pdf:
#  - italaw11080.pdf (Similarity: 1.00)
#  - italaw10594_0.pdf (Similarity: 0.47)
#  - italaw10213.pdf (Similarity: 0.43)
#  - italaw10817.pdf (Similarity: 0.40)
#  - italaw4244.pdf (Similarity: 0.38)
#
# Top neighbors for italaw16068.pdf:
#  - italaw16067.pdf (Similarity: 0.46)
#  - italaw16071.pdf (Similarity: 0.43)
#  - 180604.pdf (Similarity: 0.40)
#  - italaw1163.pdf (Similarity: 0.40)
#  - italaw16368.pdf (Similarity: 0.38)
#
# Top neighbors for ita0446.pdf:
#  - ita0348.pdf (Similarity: 1.00)
#  - italaw3029.pdf (Similarity: 0.63)
#  - italaw3026.pdf (Similarity: 0.63)
#  - italaw3027_0.pdf (Similarity: 0.56)
#  - italaw3027.pdf (Similarity: 0.56)
#
# Top neighbors for italaw16384.pdf:
#  - italaw170357.pdf (Similarity: 0.75)
#  - italaw16385.pdf (Similarity: 0.69)
#  - italaw16386.pdf (Similarity: 0.68)
#  - italaw16383.pdf (Similarity: 0.66)
#  - italaw16387.pdf (Similarity: 0.64)
#
# Top neighbors for italaw6309.pdf:
#  - italaw4043.pdf (Similarity: 0.44)
#  - ita0878.pdf (Similarity: 0.35)
#  - ita0768.pdf (Similarity: 0.34)
#  - ita0479.pdf (Similarity: 0.33)
#  - ita0108.pdf (Similarity: 0.33)
#
# Top neighbors for italaw7680_2.pdf:
#  - italaw11557_0.pdf (Similarity: 0.92)
#  - italaw9937.pdf (Similarity: 0.90)
#  - italaw9939.pdf (Similarity: 0.88)
#  - italaw170039.pdf (Similarity: 0.87)
#  - italaw7681.pdf (Similarity: 0.76)
#
# Top neighbors for 18029.pdf:
#  - italaw9869.pdf (Similarity: 0.28)
#  - italaw16160.pdf (Similarity: 0.27)
#  - italaw170969.pdf (Similarity: 0.26)
#  - 18030.pdf (Similarity: 0.24)
#  - italaw4073.pdf (Similarity: 0.23)
#
# Top neighbors for italaw6267.pdf:
#  - italaw7877.pdf (Similarity: 0.66)
#  - italaw7881_0.pdf (Similarity: 0.63)
#  - italaw7881.pdf (Similarity: 0.63)
#  - italaw7880.pdf (Similarity: 0.54)
#  - italaw7878_0.pdf (Similarity: 0.49)
#
# Top neighbors for italaw180869.pdf:
#  - 180385.pdf (Similarity: 0.71)
#  - italaw11903.pdf (Similarity: 0.41)
#  - italaw10010.pdf (Similarity: 0.37)
#  - italaw181605.pdf (Similarity: 0.30)
#  - ita0264.pdf (Similarity: 0.28)
#
# Top neighbors for italaw8772.pdf:
#  - italaw3247.pdf (Similarity: 0.55)
#  - 180792.pdf (Similarity: 0.54)
#  - italaw182324.pdf (Similarity: 0.54)
#  - italaw11183.pdf (Similarity: 0.53)
#  - italaw8842.pdf (Similarity: 0.50)
#
# Top neighbors for italaw9951.pdf:
#  - italaw170482.pdf (Similarity: 0.77)
#  - italaw170481.pdf (Similarity: 0.66)
#  - italaw9672.pdf (Similarity: 0.65)
#  - italaw7385.pdf (Similarity: 0.65)
#  - italaw9284.pdf (Similarity: 0.57)
#
# Top neighbors for italaw9904.pdf:
#  - italaw9243.pdf (Similarity: 0.47)
#  - italaw9012.pdf (Similarity: 0.46)
#  - italaw9907.pdf (Similarity: 0.42)
#  - italaw9900.pdf (Similarity: 0.41)
#  - italaw10921.pdf (Similarity: 0.39)
#
# Top neighbors for italaw170268.pdf:
#  - italaw170324.pdf (Similarity: 0.68)
#  - 180298.pdf (Similarity: 0.27)
#  - italaw170991_0.pdf (Similarity: 0.24)
#  - italaw170991.pdf (Similarity: 0.24)
#  - italaw170789.pdf (Similarity: 0.24)
#
# Top neighbors for italaw11321.pdf:
#  - italaw9319.pdf (Similarity: 0.83)
#  - italaw11688.pdf (Similarity: 0.79)
#  - italaw9880.pdf (Similarity: 0.76)
#  - 180469.pdf (Similarity: 0.74)
#  - italaw170536.pdf (Similarity: 0.74)
#
# Top neighbors for italaw171167.pdf:
#  - italaw10808.pdf (Similarity: 0.62)
#  - italaw11557_0.pdf (Similarity: 0.57)
#  - italaw170039.pdf (Similarity: 0.56)
#  - italaw7680_2.pdf (Similarity: 0.55)
#  - italaw9939.pdf (Similarity: 0.55)
#
# Top neighbors for italaw4333.pdf:
#  - italaw10703.pdf (Similarity: 0.74)
#  - italaw7300.pdf (Similarity: 0.61)
#  - italaw4103.pdf (Similarity: 0.58)
#  - italaw7299.pdf (Similarity: 0.58)
#  - italaw11456.pdf (Similarity: 0.56)
#
# Top neighbors for italaw8421.pdf:
#  - italaw9532_0.pdf (Similarity: 1.00)
#  - italaw9531.pdf (Similarity: 1.00)
#  - italaw9530.pdf (Similarity: 1.00)
#  - italaw9529_0.pdf (Similarity: 1.00)
#  - italaw9528.pdf (Similarity: 1.00)
#
# Top neighbors for italaw170264.pdf:
#  - italaw170979.pdf (Similarity: 0.61)
#  - italaw170981.pdf (Similarity: 0.50)
#  - 180113_0.pdf (Similarity: 0.44)
#  - italaw180821.pdf (Similarity: 0.35)
#  - italaw10252.pdf (Similarity: 0.18)
#
# Top neighbors for 180076.pdf:
#  - 180074_0.pdf (Similarity: 0.46)
#  - 180074.pdf (Similarity: 0.46)
#  - 180075.pdf (Similarity: 0.38)
#  - 180072.pdf (Similarity: 0.37)
#  - italaw11797.pdf (Similarity: 0.24)
#
# Top neighbors for italaw1415.pdf:
#  - italaw1414.pdf (Similarity: 0.86)
#  - italaw1140_0.pdf (Similarity: 0.83)
#  - italaw3073_0.pdf (Similarity: 0.63)
#  - ita0249_0.pdf (Similarity: 0.62)
#  - italaw1555.pdf (Similarity: 0.62)
#
# Top neighbors for italaw7243.pdf:
#  - italaw7245.pdf (Similarity: 0.59)
#  - italaw7306.pdf (Similarity: 0.56)
#  - italaw7401.pdf (Similarity: 0.51)
#  - italaw7399_11.pdf (Similarity: 0.51)
#  - italaw4264.pdf (Similarity: 0.49)
#
# Top neighbors for italaw3114.pdf:
#  - italaw10483.pdf (Similarity: 0.49)
#  - ita0177.pdf (Similarity: 0.41)
#  - italaw4316.pdf (Similarity: 0.41)
#  - italaw4094.pdf (Similarity: 0.35)
#  - italaw9934.pdf (Similarity: 0.34)
#
# ...
#  - italaw8677.pdf (Similarity: 0.44)
#  - ita0122.pdf (Similarity: 0.42)
#
# Top neighbors for italaw11105.pdf:
#  - italaw11032.pdf (Similarity: 0.83)
#  - italaw11627.pdf (Similarity: 0.46)
#  - italaw10644.pdf (Similarity: 0.35)
#  - italaw11459.pdf (Similarity: 0.22)
#  - italaw11035.pdf (Similarity: 0.18)
#
# Top neighbors for italaw10928.pdf:
#  - italaw10929.pdf (Similarity: 0.93)
#  - italaw10930.pdf (Similarity: 0.91)
#  - italaw10931.pdf (Similarity: 0.64)
#  - italaw10936.pdf (Similarity: 0.41)
#  - italaw171355_0.pdf (Similarity: 0.41)
#
# Top neighbors for italaw9618.pdf:
#  - italaw4479.pdf (Similarity: 0.65)
#  - italaw10213.pdf (Similarity: 0.49)
#  - italaw10817.pdf (Similarity: 0.47)
#  - italaw10594_0.pdf (Similarity: 0.44)
#  - 180764.pdf (Similarity: 0.36)
#
# Top neighbors for ita0757.pdf:
#  - ita0910.pdf (Similarity: 0.31)
#  - ita0411.pdf (Similarity: 0.31)
#  - ita0891.pdf (Similarity: 0.31)
#  - italaw4153_0_0.pdf (Similarity: 0.31)
#  - italaw4153_0.pdf (Similarity: 0.31)
#
# Top neighbors for italaw170916.pdf:
#  - 180231.pdf (Similarity: 0.79)
#  - italaw170912.pdf (Similarity: 0.78)
#  - italaw170915.pdf (Similarity: 0.77)
#  - italaw8531.pdf (Similarity: 0.76)
#  - italaw170911.pdf (Similarity: 0.76)
#
# Top neighbors for italaw1491.pdf:
#  - italaw1286.pdf (Similarity: 0.71)
#  - ita0395.pdf (Similarity: 0.69)
#  - italaw1139.pdf (Similarity: 0.60)
#  - ita0386_0.pdf (Similarity: 0.57)
#  - italaw3293.pdf (Similarity: 0.45)
#
# Top neighbors for 180653.pdf:
#  - italaw11997.pdf (Similarity: 0.74)
#  - italaw16346.pdf (Similarity: 0.59)
#  - italaw11209.pdf (Similarity: 0.58)
#  - italaw11885.pdf (Similarity: 0.58)
#  - 180369.pdf (Similarity: 0.57)
#
# Top neighbors for italaw16415.pdf:
#  - italaw4305.pdf (Similarity: 0.60)
#  - italaw8026.pdf (Similarity: 0.59)
#  - italaw8536.pdf (Similarity: 0.58)
#  - italaw3261.pdf (Similarity: 0.57)
#  - italaw10514.pdf (Similarity: 0.57)
#
# Top neighbors for ita0352.pdf:
#  - italaw10367.pdf (Similarity: 0.61)
#  - ita0415.pdf (Similarity: 0.27)
#  - ita0920.pdf (Similarity: 0.27)
#  - ita0409.pdf (Similarity: 0.26)
#  - italaw7315_0.pdf (Similarity: 0.25)
#
# Top neighbors for italaw11829.pdf:
#  - italaw11830.pdf (Similarity: 0.64)
#  - italaw11831.pdf (Similarity: 0.60)
#  - italaw180845.pdf (Similarity: 0.38)
#  - italaw7163_1.pdf (Similarity: 0.22)
#  - italaw16136.pdf (Similarity: 0.20)
#
# Top neighbors for italaw7494_1.pdf:
#  - italaw7495_0.pdf (Similarity: 0.71)
#  - ita0907.pdf (Similarity: 0.58)
#  - italaw170796.pdf (Similarity: 0.57)
#  - italaw9383.pdf (Similarity: 0.55)
#  - italaw1540.pdf (Similarity: 0.54)
#
# Top neighbors for italaw7522.pdf:
#  - italaw7064.pdf (Similarity: 0.54)
#  - italaw4458.pdf (Similarity: 0.46)
#  - italaw9381.pdf (Similarity: 0.44)
#  - italaw9014.pdf (Similarity: 0.43)
#  - italaw8484.pdf (Similarity: 0.41)
#
# Top neighbors for italaw181305.pdf:
#  - italaw181304.pdf (Similarity: 0.79)
#  - italaw182476.pdf (Similarity: 0.24)
#  - italaw16161.pdf (Similarity: 0.17)
#  - italaw10701.pdf (Similarity: 0.17)
#  - italaw171121.pdf (Similarity: 0.16)
#
# Top neighbors for italaw8119.pdf:
#  - italaw80101.pdf (Similarity: 0.49)
#  - italaw8123.pdf (Similarity: 0.48)
#  - italaw80102.pdf (Similarity: 0.48)
#  - italaw8086_1.pdf (Similarity: 0.48)
#  - italaw10322.pdf (Similarity: 0.45)
#
# Top neighbors for italaw8021.pdf:
#  - italaw11612.pdf (Similarity: 0.17)
#  - italaw11610.pdf (Similarity: 0.15)
#  - italaw10055.pdf (Similarity: 0.14)
#  - italw180813.pdf (Similarity: 0.12)
#  - italaw3174_0.pdf (Similarity: 0.12)
#
# Top neighbors for italaw3261.pdf:
#  - italaw4305.pdf (Similarity: 0.63)
#  - italaw16415.pdf (Similarity: 0.57)
#  - italaw11799.pdf (Similarity: 0.56)
#  - italaw170784.pdf (Similarity: 0.56)
#  - italaw6274.pdf (Similarity: 0.55)
#
# Top neighbors for italaw8566.pdf:
#  - italaw8280.pdf (Similarity: 1.00)
#  - italaw8956.pdf (Similarity: 0.72)
#  - italaw8478.pdf (Similarity: 0.69)
#  - italaw8826.pdf (Similarity: 0.67)
#  - italaw8281.pdf (Similarity: 0.60)
#
# Top neighbors for ita0472.pdf:
#  - ita0474.pdf (Similarity: 0.64)
#  - ita0473.pdf (Similarity: 0.63)
#  - ita0475.pdf (Similarity: 0.47)
#  - italaw9074.pdf (Similarity: 0.45)
#  - italaw9075.pdf (Similarity: 0.44)
#
# Top neighbors for italaw9197.pdf:
#  - italaw9883.pdf (Similarity: 0.68)
#  - italaw9882.pdf (Similarity: 0.58)
#  - italaw10227.pdf (Similarity: 0.51)
#  - italaw10226.pdf (Similarity: 0.47)
#  - italaw10228.pdf (Similarity: 0.46)
#
# Top neighbors for italaw10668.pdf:
#  - italaw10674.pdf (Similarity: 0.92)
#  - italaw10678.pdf (Similarity: 0.90)
#  - italaw10671.pdf (Similarity: 0.90)
#  - italaw9809.pdf (Similarity: 0.71)
#  - 180627_0.pdf (Similarity: 0.58)
#
# Top neighbors for italaw10788.pdf:
#  - italaw180849.pdf (Similarity: 0.51)
#  - italaw180847.pdf (Similarity: 0.43)
#  - italaw10195.pdf (Similarity: 0.41)
#  - italaw180895_0.pdf (Similarity: 0.40)
#  - italaw170491.pdf (Similarity: 0.40)
#
# Top neighbors for ita0413.pdf:
#  - ita1021.pdf (Similarity: 0.64)
#  - ita1060.pdf (Similarity: 0.28)
#  - ita0547.pdf (Similarity: 0.27)
#  - italaw7942_0.pdf (Similarity: 0.27)
#  - italaw7940.pdf (Similarity: 0.26)
#
# Top neighbors for italaw7734.pdf:
#  - italaw16345.pdf (Similarity: 0.62)
#  - italaw16077.pdf (Similarity: 0.52)
#  - 180376.pdf (Similarity: 0.52)
#  - italaw16475.pdf (Similarity: 0.50)
#  - italaw182366.pdf (Similarity: 0.47)
#
# Top neighbors for italaw3162.pdf.pdf:
#  - italaw10508.pdf (Similarity: 0.60)
#  - italaw4354.pdf (Similarity: 0.59)
#  - italaw16216.pdf (Similarity: 0.54)
#  - italaw8015.pdf (Similarity: 0.53)
#  - italaw9724.pdf (Similarity: 0.51)
#
# Top neighbors for ita0572.pdf:
#  - ita0573.pdf (Similarity: 0.73)
#  - ita0574.pdf (Similarity: 0.46)
#  - ita1060.pdf (Similarity: 0.42)
#  - ita1061.pdf (Similarity: 0.41)
#  - ita0575.pdf (Similarity: 0.40)
#
# Top neighbors for italaw1419.pdf:
#  - italaw3075.pdf (Similarity: 0.60)
#  - italaw1417.pdf (Similarity: 0.59)
#  - italaw3105_0.pdf (Similarity: 0.57)
#  - italaw3122.pdf (Similarity: 0.57)
#  - italaw4255.pdf (Similarity: 0.56)
#
# Top neighbors for ita0812.pdf:
#  - ita0054.pdf (Similarity: 1.00)
#  - ita0262.pdf (Similarity: 0.81)
#  - italaw6302.pdf (Similarity: 0.56)
#  - italaw9845.pdf (Similarity: 0.53)
#  - italaw9844.pdf (Similarity: 0.53)
#
# Top neighbors for 180645.pdf:
#  - 180639.pdf (Similarity: 0.39)
#  - italaw11691.pdf (Similarity: 0.36)
#  - italaw9987_0.pdf (Similarity: 0.31)
#  - italaw180818.pdf (Similarity: 0.31)
#  - italaw171029.pdf (Similarity: 0.29)
#
# Top neighbors for italaw10601.pdf:
#  - italaw10599.pdf (Similarity: 0.57)
#  - italaw10600.pdf (Similarity: 0.50)
#  - italaw4254.pdf (Similarity: 0.33)
#  - ita0726.pdf (Similarity: 0.27)
#  - ita0279.pdf (Similarity: 0.24)
#
# Top neighbors for ita0445.pdf:
#  - ita0347.pdf (Similarity: 1.00)
#  - ita0444.pdf (Similarity: 0.67)
#  - ita0446.pdf (Similarity: 0.40)
#  - ita0348.pdf (Similarity: 0.40)
#  - italaw3027_0.pdf (Similarity: 0.39)
#
# Top neighbors for ita0471_0.pdf:
#  - italaw9075.pdf (Similarity: 0.60)
#  - italaw9076.pdf (Similarity: 0.56)
#  - italaw9078.pdf (Similarity: 0.54)
#  - italaw9074.pdf (Similarity: 0.54)
#  - ita0474.pdf (Similarity: 0.45)
#
# Top neighbors for italaw11331.pdf:
#  - italaw10296.pdf (Similarity: 0.47)
#  - italaw10529.pdf (Similarity: 0.44)
#  - italaw11405.pdf (Similarity: 0.28)
#  - italaw8567.pdf (Similarity: 0.26)
#  - italaw11330.pdf (Similarity: 0.25)
#
# Top neighbors for italaw7454.pdf:
#  - italaw7454_0.pdf (Similarity: 1.00)
#  - italaw7629.pdf (Similarity: 0.87)
#  - italaw7628.pdf (Similarity: 0.87)
#  - italaw8738.pdf (Similarity: 0.83)
#  - italaw8736.pdf (Similarity: 0.83)
#
# Top neighbors for italaw8490.pdf:
#  - italaw9532_0.pdf (Similarity: 1.00)
#  - italaw9531.pdf (Similarity: 1.00)
#  - italaw9530.pdf (Similarity: 1.00)
#  - italaw9529_0.pdf (Similarity: 1.00)
#  - italaw9528.pdf (Similarity: 1.00)
#
# Top neighbors for italaw9186.pdf:
#  - italaw4160.pdf (Similarity: 0.50)
#  - italaw9052.pdf (Similarity: 0.47)
#  - italaw9225.pdf (Similarity: 0.47)
#  - italaw8946.pdf (Similarity: 0.45)
#  - italaw9877.pdf (Similarity: 0.41)
#
# Top neighbors for italaw3109.pdf:
#  - italaw3111.pdf (Similarity: 0.92)
#  - italaw1320.pdf (Similarity: 0.64)
#  - ita0033.pdf (Similarity: 0.51)
#  - italaw170950.pdf (Similarity: 0.21)
#  - italaw11040.pdf (Similarity: 0.17)
#
# Top neighbors for italaw8434.pdf:
#  - italaw9532_0.pdf (Similarity: 1.00)
#  - italaw9531.pdf (Similarity: 1.00)
#  - italaw9530.pdf (Similarity: 1.00)
#  - italaw9529_0.pdf (Similarity: 1.00)
#  - italaw9528.pdf (Similarity: 1.00)
#
# Top neighbors for italaw11346.pdf:
#  - italaw11347.pdf (Similarity: 0.62)
#  - ita0725.pdf (Similarity: 0.35)
#  - italaw8028_0.pdf (Similarity: 0.33)
#  - italaw16050.pdf (Similarity: 0.31)
#  - italaw4108.pdf (Similarity: 0.30)
#
# Top neighbors for italaw170815.pdf:
#  - italaw170917.pdf (Similarity: 0.50)
#  - 180268.pdf (Similarity: 0.44)
#  - italaw171050.pdf (Similarity: 0.42)
#  - italaw170918.pdf (Similarity: 0.41)
#  - italaw170318.pdf (Similarity: 0.37)
#
# Top neighbors for italaw7581.pdf:
#  - italaw7583.pdf (Similarity: 0.83)
#  - italaw7744_1.pdf (Similarity: 0.78)
#  - italaw7580.pdf (Similarity: 0.76)
#  - italaw4398.pdf (Similarity: 0.74)
#  - italaw7434.pdf (Similarity: 0.72)
#
# Top neighbors for italaw8469.pdf:
#  - italaw8468.pdf (Similarity: 0.78)
#  - italaw8466.pdf (Similarity: 0.78)
#  - italaw8467.pdf (Similarity: 0.71)
#  - italaw8471.pdf (Similarity: 0.66)
#  - italaw9662.pdf (Similarity: 0.52)
#
# Top neighbors for italaw171348.pdf:
#  - italaw16130.pdf (Similarity: 0.88)
#  - italaw16433_0.pdf (Similarity: 0.82)
#  - italaw10647.pdf (Similarity: 0.82)
#  - italaw11902.pdf (Similarity: 0.80)
#  - italaw10183.pdf (Similarity: 0.78)
#
# Top neighbors for italaw170825.pdf:
#  - 180205.pdf (Similarity: 0.77)
#  - 180193.pdf (Similarity: 0.76)
#  - 180194.pdf (Similarity: 0.74)
#  - 180195.pdf (Similarity: 0.74)
#  - italaw170310.pdf (Similarity: 0.69)
#
# Top neighbors for italaw1333.pdf:
#  - italaw1282.pdf (Similarity: 0.70)
#  - italaw1284.pdf (Similarity: 0.63)
#  - italaw1289.pdf (Similarity: 0.62)
#  - italaw1218.pdf (Similarity: 0.56)
#  - italaw1395.pdf (Similarity: 0.54)
#
# Top neighbors for italaw7114.pdf:
#  - italaw7148.pdf (Similarity: 0.43)
#  - italaw7263.pdf (Similarity: 0.36)
#  - italaw7264.pdf (Similarity: 0.35)
#  - italaw7143.pdf (Similarity: 0.34)
#  - italaw4386.pdf (Similarity: 0.28)
#
# Top neighbors for italaw9925.pdf:
#  - italaw9649.pdf (Similarity: 0.74)
#  - italaw9264.pdf (Similarity: 0.67)
#  - italaw9265.pdf (Similarity: 0.67)
#  - italaw9622.pdf (Similarity: 0.64)
#  - italaw9760_0.pdf (Similarity: 0.64)
#
# Top neighbors for italaw8185.pdf:
#  - italaw8181.pdf (Similarity: 0.80)
#  - italaw8183.pdf (Similarity: 0.65)
#  - italaw8159_0.pdf (Similarity: 0.65)
#  - italaw8171_1.pdf (Similarity: 0.59)
#  - italaw8169_0.pdf (Similarity: 0.58)
#
# Top neighbors for italaw1596.pdf:
#  - italaw1156.pdf (Similarity: 0.97)
#  - italaw4259.pdf (Similarity: 0.79)
#  - italaw171018.pdf (Similarity: 0.55)
#  - italaw9311.pdf (Similarity: 0.50)
#  - italaw171020.pdf (Similarity: 0.28)
#
# Top neighbors for italaw1489_0.pdf:
#  - italaw1161_0.pdf (Similarity: 0.88)
#  - italaw4212.pdf (Similarity: 0.72)
#  - italaw9495.pdf (Similarity: 0.67)
#  - italaw6282.pdf (Similarity: 0.65)
#  - italaw6275.pdf (Similarity: 0.64)
#
# Top neighbors for italaw11873.pdf:
#  - italaw16322_0.pdf (Similarity: 0.86)
#  - italaw10631.pdf (Similarity: 0.81)
#  - italaw170924.pdf (Similarity: 0.70)
#  - italaw182328.pdf (Similarity: 0.61)
#  - italaw170581.pdf (Similarity: 0.44)
#
# Top neighbors for italaw10433.pdf:
#  - italaw10757.pdf (Similarity: 0.62)
#  - italaw10092.pdf (Similarity: 0.56)
#  - italaw11077_0.pdf (Similarity: 0.56)
#  - italaw11364.pdf (Similarity: 0.53)
#  - italaw10630.pdf (Similarity: 0.48)
#
# Top neighbors for italaw16582_0.pdf:
#  - italaw16582_1.pdf (Similarity: 1.00)
#  - italaw16582.pdf (Similarity: 1.00)
#  - italaw16581_1.pdf (Similarity: 0.61)
#  - italaw16581_0.pdf (Similarity: 0.61)
#  - italaw16581.pdf (Similarity: 0.61)
#
# Top neighbors for italaw9876.pdf:
#  - italaw9875.pdf (Similarity: 0.87)
#  - italaw11234_0.pdf (Similarity: 0.72)
#  - italaw11056.pdf (Similarity: 0.70)
#  - italaw10455_0.pdf (Similarity: 0.64)
#  - italaw10692.pdf (Similarity: 0.61)
#
# Top neighbors for italaw11813.pdf:
#  - italaw11484.pdf (Similarity: 0.66)
#  - italaw16112.pdf (Similarity: 0.56)
#  - italaw170837.pdf (Similarity: 0.53)
#  - italaw11885.pdf (Similarity: 0.52)
#  - italaw170599.pdf (Similarity: 0.52)
#
# Top neighbors for italaw6365.pdf:
#  - italaw6319.pdf (Similarity: 0.88)
#  - italaw7434.pdf (Similarity: 0.74)
#  - italaw6338.pdf (Similarity: 0.73)
#  - italaw4394.pdf (Similarity: 0.72)
#  - italaw4396.pdf (Similarity: 0.71)
#
# Top neighbors for 180553.pdf:
#  - 180552.pdf (Similarity: 0.61)
#  - 180551.pdf (Similarity: 0.59)
#  - italaw4287.pdf (Similarity: 0.59)
#  - italaw170598.pdf (Similarity: 0.59)
#  - 180238.pdf (Similarity: 0.59)
#
# Top neighbors for italaw11511.pdf:
#  - italaw11223.pdf (Similarity: 0.59)
#  - italaw10284.pdf (Similarity: 0.52)
#  - italaw9987_0.pdf (Similarity: 0.49)
#  - italaw10280.pdf (Similarity: 0.44)
#  - italaw10722.pdf (Similarity: 0.40)
#
# Top neighbors for italaw8234.pdf:
#  - italaw7489_0.pdf (Similarity: 0.65)
#  - ita0547.pdf (Similarity: 0.49)
#  - italaw8636.pdf (Similarity: 0.41)
#  - ita1007.pdf (Similarity: 0.37)
#  - ita0294.pdf (Similarity: 0.37)
#
# Top neighbors for italaw9993.pdf:
#  - italaw9989_0.pdf (Similarity: 0.53)
#  - italaw9929.pdf (Similarity: 0.42)
#  - italaw4251.pdf (Similarity: 0.27)
#  - 180264.pdf (Similarity: 0.27)
#  - 180764.pdf (Similarity: 0.26)
#
# Top neighbors for ita0831.pdf:
#  - ita0834.pdf (Similarity: 0.36)
#  - ita0832.pdf (Similarity: 0.16)
#  - ita0840.pdf (Similarity: 0.13)
#  - ita0848.pdf (Similarity: 0.13)
#  - ita0846.pdf (Similarity: 0.13)
#
# Top neighbors for italaw7433.pdf:
#  - italaw7432_0.pdf (Similarity: 1.00)
#  - italaw180959.pdf (Similarity: 0.79)
#  - italaw180958.pdf (Similarity: 0.79)
#  - italaw180957.pdf (Similarity: 0.79)
#  - italaw180956.pdf (Similarity: 0.66)
#
# Top neighbors for italaw7611.pdf:
#  - italaw7708.pdf (Similarity: 0.72)
#  - italaw7213.pdf (Similarity: 0.66)
#  - italaw11742.pdf (Similarity: 0.50)
#  - italaw7166.pdf (Similarity: 0.44)
#  - italaw7163_1.pdf (Similarity: 0.44)
#
# Top neighbors for italaw4011.pdf:
#  - italaw8536.pdf (Similarity: 0.56)
#  - ita0538.pdf (Similarity: 0.56)
#  - italaw170693.pdf (Similarity: 0.42)
#  - italaw1569.pdf (Similarity: 0.37)
#  - 180501.pdf (Similarity: 0.36)
#
# Top neighbors for italaw3010.pdf:
#  - italaw1242.pdf (Similarity: 0.96)
#  - italaw1260.pdf (Similarity: 0.91)
#  - italaw3324.pdf (Similarity: 0.83)
#  - italaw3002.pdf (Similarity: 0.75)
#  - italaw1236.pdf (Similarity: 0.74)
#
# Top neighbors for italaw10666.pdf:
#  - italaw11735.pdf (Similarity: 0.65)
#  - italaw9914.pdf (Similarity: 0.65)
#  - italaw9511.pdf (Similarity: 0.64)
#  - italaw8957.pdf (Similarity: 0.64)
#  - italaw10664.pdf (Similarity: 0.60)
#
# Top neighbors for ita0716.pdf:
#  - italaw1487.pdf (Similarity: 0.21)
#  - ita0268_0.pdf (Similarity: 0.20)
#  - italaw3319.pdf (Similarity: 0.19)
#  - ita0439.pdf (Similarity: 0.19)
#  - italaw8549.pdf (Similarity: 0.19)
#
# Top neighbors for italaw1178.pdf:
#  - italaw9707.pdf (Similarity: 0.81)
#  - italaw10286.pdf (Similarity: 0.81)
#  - italaw10287.pdf (Similarity: 0.75)
#  - italaw11480_0.pdf (Similarity: 0.65)
#  - italaw10340.pdf (Similarity: 0.62)
#
# Top neighbors for italaw16058.pdf:
#  - italaw16079.pdf (Similarity: 0.97)
#  - italaw16083.pdf (Similarity: 0.97)
#  - italaw16086.pdf (Similarity: 0.94)
#  - italaw16051.pdf (Similarity: 0.83)
#  - italaw16066.pdf (Similarity: 0.66)
#
# Top neighbors for italaw16072.pdf:
#  - italaw16076.pdf (Similarity: 0.71)
#  - italaw16074.pdf (Similarity: 0.62)
#  - italaw16082.pdf (Similarity: 0.55)
#  - italaw16065.pdf (Similarity: 0.53)
#  - italaw16066.pdf (Similarity: 0.51)
#
# Top neighbors for italaw11567.pdf:
#  - italaw11595.pdf (Similarity: 0.67)
#  - italaw11568.pdf (Similarity: 0.54)
#  - italaw11569.pdf (Similarity: 0.34)
#  - italaw11572.pdf (Similarity: 0.20)
#  - italaw11273.pdf (Similarity: 0.18)
#
# Top neighbors for italaw182568.pdf:
#  - italaw182566.pdf (Similarity: 0.64)
#  - italaw16001.pdf (Similarity: 0.56)
#  - italaw16422.pdf (Similarity: 0.52)
#  - italaw170940.pdf (Similarity: 0.46)
#  - italaw170942.pdf (Similarity: 0.46)
#
# Top neighbors for ita0933.pdf:
#  - ita1073_0.pdf (Similarity: 0.53)
#  - italaw7440.pdf (Similarity: 0.37)
#  - italaw11589.pdf (Similarity: 0.30)
#  - italaw8820.pdf (Similarity: 0.30)
#  - italaw4227.pdf (Similarity: 0.29)

# %%
# Step 5: Save graph to JSON
# output_json_path = "/Users/taclin/Desktop/study/taming big data/final_project/scores/neighbor_graph.json"x
save_graph_to_json(similarity_graph, output_json_path)
print(f"\nNeighbor graph saved to {output_json_path}")
# Out:
# Neighbor graph saved to /Users/taclin/Desktop/study/taming big data/final_project/scores/neighbor_graph.json

# %%
import PyPDF2

with open('Arbitration 2.pdf', 'rb') as file:
    reader = PyPDF2.PdfReader(file)
    text = ''
    for page in reader.pages:
        text += page.extract_text()

print(text)
# Out:
# -----------------------------------------------------------------------------------------------------------------------------------------------------------Modak, (2008) 1 SCC 1 paras 61, 62 & 63.this judgment is protected by the law declared by the Supreme Court in Eastern Book Company v. D.B.TruePrint™ source:  Supreme Court Cases, © 2025 Eastern Book Company. The text of this version ofSCC Online Web Edition: https://www.scconline.comPrinted For: Pallavi PratapPage 1         Sunday, January 05, 2025SCC Online Web Edition, © 2025 EBC Publishing Pvt. Ltd.-----------------------------------------------------------------------------------------------------------------------------------------------------------Modak, (2008) 1 SCC 1 paras 61, 62 & 63.this judgment is protected by the law declared by the Supreme Court in Eastern Book Company v. D.B.TruePrint™ source:  Supreme Court Cases, © 2025 Eastern Book Company. The text of this version ofSCC Online Web Edition: https://www.scconline.comPrinted For: Pallavi PratapPage 2         Sunday, January 05, 2025SCC Online Web Edition, © 2025 EBC Publishing Pvt. Ltd.-----------------------------------------------------------------------------------------------------------------------------------------------------------Modak, (2008) 1 SCC 1 paras 61, 62 & 63.this judgment is protected by the law declared by the Supreme Court in Eastern Book Company v. D.B.TruePrint™ source:  Supreme Court Cases, © 2025 Eastern Book Company. The text of this version ofSCC Online Web Edition: https://www.scconline.comPrinted For: Pallavi PratapPage 3         Sunday, January 05, 2025SCC Online Web Edition, © 2025 EBC Publishing Pvt. Ltd.-----------------------------------------------------------------------------------------------------------------------------------------------------------Modak, (2008) 1 SCC 1 paras 61, 62 & 63.this judgment is protected by the law declared by the Supreme Court in Eastern Book Company v. D.B.TruePrint™ source:  Supreme Court Cases, © 2025 Eastern Book Company. The text of this version ofSCC Online Web Edition: https://www.scconline.comPrinted For: Pallavi PratapPage 4         Sunday, January 05, 2025SCC Online Web Edition, © 2025 EBC Publishing Pvt. Ltd.-----------------------------------------------------------------------------------------------------------------------------------------------------------Modak, (2008) 1 SCC 1 paras 61, 62 & 63.this judgment is protected by the law declared by the Supreme Court in Eastern Book Company v. D.B.TruePrint™ source:  Supreme Court Cases, © 2025 Eastern Book Company. The text of this version ofSCC Online Web Edition: https://www.scconline.comPrinted For: Pallavi PratapPage 5         Sunday, January 05, 2025SCC Online Web Edition, © 2025 EBC Publishing Pvt. Ltd.-----------------------------------------------------------------------------------------------------------------------------------------------------------Modak, (2008) 1 SCC 1 paras 61, 62 & 63.this judgment is protected by the law declared by the Supreme Court in Eastern Book Company v. D.B.TruePrint™ source:  Supreme Court Cases, © 2025 Eastern Book Company. The text of this version ofSCC Online Web Edition: https://www.scconline.comPrinted For: Pallavi PratapPage 6         Sunday, January 05, 2025SCC Online Web Edition, © 2025 EBC Publishing Pvt. Ltd.-----------------------------------------------------------------------------------------------------------------------------------------------------------Modak, (2008) 1 SCC 1 paras 61, 62 & 63.this judgment is protected by the law declared by the Supreme Court in Eastern Book Company v. D.B.TruePrint™ source:  Supreme Court Cases, © 2025 Eastern Book Company. The text of this version ofSCC Online Web Edition: https://www.scconline.comPrinted For: Pallavi PratapPage 7         Sunday, January 05, 2025SCC Online Web Edition, © 2025 EBC Publishing Pvt. Ltd.------------------------------------------------------------------------- ...

# %%
import heapq

# --------- Main Graph Class Using Similarity Matrix ---------
class PrecomputedSimilarityGraph:
    def __init__(self, similarity_matrix, doc_ids, top_k=5):
        self.similarity_matrix = similarity_matrix
        self.doc_ids = doc_ids
        self.top_k = top_k
        self.graph = {doc_id: [] for doc_id in doc_ids}

    def initialize_graph(self):
        """Initialize heaps from the precomputed similarity matrix."""
        num_docs = len(self.doc_ids)
        
        for idx, doc_id in enumerate(self.doc_ids):
            heap = []
            for neighbor_idx, neighbor_id in enumerate(self.doc_ids):
                if neighbor_id == doc_id:
                    continue  # Skip self-similarity
                sim_score = self.similarity_matrix[idx][neighbor_idx]
                
                heapq.heappush(heap, (sim_score, neighbor_id))
                if len(heap) > self.top_k:
                    heapq.heappop(heap)  # Keep only top_k
            
            self.graph[doc_id] = heap

    def add_document(self, new_doc_id, new_similarities):
        """
        Add a new document dynamically using precomputed similarities.
        
        new_similarities: list of similarities between new_doc and existing docs.
        """
        self.graph[new_doc_id] = []

        for existing_doc_id, sim in zip(self.doc_ids, new_similarities):
            # Update new doc heap
            heapq.heappush(self.graph[new_doc_id], (sim, existing_doc_id))
            if len(self.graph[new_doc_id]) > self.top_k:
                heapq.heappop(self.graph[new_doc_id])

            # Update existing doc heap
            heapq.heappush(self.graph[existing_doc_id], (sim, new_doc_id))
            if len(self.graph[existing_doc_id]) > self.top_k:
                heapq.heappop(self.graph[existing_doc_id])

        self.doc_ids.append(new_doc_id)  # Update doc list
        self.similarity_matrix.append(new_similarities)

        # Also append similarity for new doc itself (usually 1.0)
        for i, row in enumerate(self.similarity_matrix[:-1]):
            row.append(new_similarities[i])
        self.similarity_matrix[-1].append(1.0)

    def get_top_neighbors(self, doc_id):
        """Return sorted top neighbors (highest similarity first)."""
        return sorted(self.graph.get(doc_id, []), reverse=True)

# --------- Usage Example ---------

# Assume sim_matrix is precomputed, sim_matrix[i][j] is similarity between doc_ids[i] and doc_ids[j]

# Load your precomputed similarity matrix and document IDs

# TODO: Load partial matrix from CSV
partial_matrix = sim_matrix[:3000]  # Example loading first 3000 docs
partial_doc_ids = doc_ids[:3000]

# TODO: Initialize new graph
graph = PrecomputedSimilarityGraph(partial_matrix, partial_doc_ids, top_k=5)
graph.initialize_graph()

# TODO: Insert new documents
new_doc_id = doc_ids[3000]
new_doc_similarities = sim_matrix[3000][:3000]  # Similarities of new doc with first 3000 docs
graph.add_document(new_doc_id, new_doc_similarities)

# Step 4: Query top neighbors
print(f"\nTop neighbors for {new_doc_id}:")
for sim, neighbor in graph.get_top_neighbors(new_doc_id):
    print(f" - {neighbor} (Similarity: {sim:.2f})")
# Out:
# Top neighbors for italaw180956.pdf:
#  - italaw7432_0.pdf (Similarity: 0.66)
#  - italaw180959.pdf (Similarity: 0.54)
#  - italaw180957.pdf (Similarity: 0.54)
#  - italaw170766.pdf (Similarity: 0.23)
#  - ita1074.pdf (Similarity: 0.23)

# %% [markdown]
# ## 2. Streaming Algorithm(first version)
# ## Bucketed MinHash Similarity Engine Summary
#
# This section implements a streaming-friendly system for maintaining a top-k similarity graph using MinHash and Locality-Sensitive Hashing (LSH).
#
# ---
#
# ### Components
#
# - **Preprocessing (`preprocess`)**
#   Cleans text, removes stopwords, and tokenizes into a set of informative words.
#
# - **MinHash Signature (`minhash_doc`)**
#   Compresses token sets into fixed-length signatures for approximate Jaccard similarity comparison.
#
# - **PDF Extraction (`extract_text_from_pdf`)**
#   Reads text from PDF files using PyPDF2.
#
# ---
#
# ### `ScalableSimilarityGraph` (Per-Bucket)
#
# - Uses `MinHashLSH` to find candidate similar documents.
# - Computes **true Jaccard similarity** between token sets.
# - Maintains a **top-k heap** of similar neighbors per document using `heapq`.
#
# ---
#
# ### `BucketedSimilarityEngine`
#
# - Hashes each document into one of `num_buckets` using `hash(doc_id) % num_buckets`.
# - Distributes documents across multiple independent LSH graphs.
# - During query:
#   - Converts query text into a MinHash signature.
#   - Searches all buckets for matching candidates.
#   - Computes exact Jaccard similarities and returns the global top-k results.
#
# ---
#
# ### Complexity Analysis
#
# Let:
# - `n` = total number of documents
# - `d` = number of unique tokens per document
# - `b` = number of buckets
# - `k` = number of top neighbors to maintain
# - `p` = number of hash permutations in MinHash (default: 128)
#
# **Insertion (per document):**
# - Preprocessing and tokenization: `O(d)`
# - MinHash signature computation: `O(p)`
# - LSH insertion and query: `O(log n')` where `n' ≈ n/b` (bucket size)
# - Jaccard similarity with each candidate: `O(d)`
# - Heap update: `O(log k)`
#
# **Total Insertion Time:**
# O(p + d + c·(d + log k)), where c is the number of LSH candidates
#
#
# **Query Time (per query):**
# - Preprocessing + MinHash: `O(p + d)`
# - LSH query in all `b` buckets: `O(b · log n')`
# - Candidate re-ranking by Jaccard: `O(c · d)`
# - Heap-based top-k selection: `O(c · log k)`
#
# **Space Complexity:**
# - Token storage: `O(n · d)`
# - MinHash signatures: `O(n · p)`
# - Graph (top-k neighbors): `O(n · k)`
#
# ---
#
# This structure allows fast, scalable, and localized similarity graph construction suitable for large document collections.

# %%
from datasketch import MinHashLSH, MinHash
from collections import defaultdict
import heapq
import re
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from PyPDF2 import PdfReader
import os


# ----------------------------
# Preprocessing and MinHash
# ----------------------------
def preprocess(text):
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s]', '', text)
    tokens = text.split()
    return set(token for token in tokens if token not in ENGLISH_STOP_WORDS)

def minhash_doc(tokens, num_perm=128):
    m = MinHash(num_perm=num_perm)
    for token in tokens:
        m.update(token.encode('utf8'))
    return m

def extract_text_from_pdf(pdf_path):
    try:
        reader = PdfReader(pdf_path)
        text = ""
        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:
                text += page_text
        return text
    except Exception as e:
        print(f"[ERROR] Failed to read {pdf_path}: {e}")
        return None



# ----------------------------
# Bucketed Similarity Engine
# ----------------------------
class BucketedSimilarityEngine:
    def __init__(self, num_buckets=10, threshold=0.5, top_k=5, num_perm=128):
        self.num_buckets = num_buckets
        self.threshold = threshold
        self.top_k = top_k
        self.num_perm = num_perm
        self.buckets = [ScalableSimilarityGraph(threshold, top_k, num_perm) for _ in range(num_buckets)]

    def _bucket_index(self, doc_id):
        return hash(doc_id) % self.num_buckets

    def add_document(self, doc_id, text):
        idx = self._bucket_index(doc_id)
        self.buckets[idx].add_document(doc_id, text)

    def query(self, text, global_top_k=5):
        tokens = preprocess(text)
        signature = minhash_doc(tokens, self.num_perm)
        results = []

        # Search across all buckets
        for bucket in self.buckets:
            candidates = bucket.lsh.query(signature)
            for candidate in candidates:
                candidate_tokens = bucket.doc_tokens[candidate]
                jaccard = jaccard_tokens(tokens, candidate_tokens)
                heapq.heappush(results, (jaccard, candidate))
                if len(results) > global_top_k:
                    heapq.heappop(results)

        return sorted(results, reverse=True)

# Helper class (redefined for this cell)
class ScalableSimilarityGraph:
    def __init__(self, threshold=0.5, top_k=5, num_perm=128):
        self.threshold = threshold
        self.top_k = top_k
        self.num_perm = num_perm
        
        self.lsh = MinHashLSH(threshold=self.threshold, num_perm=self.num_perm)
        self.doc_signatures = {}  # doc_id -> MinHash signature
        self.doc_tokens = {}  # doc_id -> token set
        self.graph = defaultdict(list)  # doc_id -> min-heap of (similarity, neighbor_doc_id)

    def add_document(self, doc_id, text):
        tokens = preprocess(text)
        signature = minhash_doc(tokens, self.num_perm)

        self.doc_signatures[doc_id] = signature
        self.doc_tokens[doc_id] = tokens
        self.lsh.insert(doc_id, signature)

        candidates = self.lsh.query(signature)
        for existing_id in candidates:
            if existing_id == doc_id:
                continue
            sim = self.true_jaccard(doc_id, existing_id)
            
            # Create a new heap for doc_id
            heapq.heappush(self.graph[doc_id], (sim, existing_id))
            if len(self.graph[doc_id]) > self.top_k:
                heapq.heappop(self.graph[doc_id])

            # Update the existing doc_id
            heapq.heappush(self.graph[existing_id], (sim, doc_id))
            if len(self.graph[existing_id]) > self.top_k:
                heapq.heappop(self.graph[existing_id])

    def true_jaccard(self, doc_id1, doc_id2):
        set1 = self.doc_tokens[doc_id1]
        set2 = self.doc_tokens[doc_id2]
        if not set1 or not set2:
            return 0
        return len(set1 & set2) / len(set1 | set2)

    def get_top_neighbors(self, doc_id):
        return sorted(self.graph.get(doc_id, []), reverse=True)

def jaccard_tokens(tokens1, tokens2):
    return len(tokens1 & tokens2) / len(tokens1 | tokens2)

# %%
import os

# Initialize Sketch
stream_graph = BucketedSimilarityEngine(num_buckets=5, threshold=0.5, top_k=5, num_perm=128)
# read all pdf files under "docs/"

files = os.listdir('docs/')
for file in files:
    if file.endswith('.pdf'):
        file_path = 'docs/' + file
        text = extract_text_from_pdf(file_path)
        if text:
            stream_graph.add_document(doc_id=file, text=text)

#
# Out:
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x47ee for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x48df for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x601e for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x4b08 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3266 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2586 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x278c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2100 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3af5 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2511 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x40ec for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2f76 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3317 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2be6 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3b64 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2530 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3bf0 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2268 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x30ea for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x31f7 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3c82 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2706 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x306c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2864 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2be5 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x339a for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2f48 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3e50 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x26e4 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2763 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2cec for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3903 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x31a8 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x21a1 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x350a for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3240 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2e09 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3b83 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x307b for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x26a1 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x20e8 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x38e4 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x288f for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Overwriting cache for 0 65

# %%
text = extract_text_from_pdf('docs/italaw11470.pdf')
clean_text = preprocess(text)
stream_graph.query(text)
# Out:
# [(1.0, 'italaw11470.pdf'),
#  (0.1548140043763676, 'italaw10420.pdf'),
#  (0.15257439773264053, 'italaw181037.pdf'),
#  (0.14168466522678186, 'ita0287_0.pdf')]

# %%
for file in files:
    if file.endswith('.pdf'):
        file_path = 'docs/' + file
        text = extract_text_from_pdf(file_path)
        print(stream_graph.query(text))
# Out:
# [(1.0, 'italaw11470.pdf'), (0.1548140043763676, 'italaw10420.pdf'), (0.15257439773264053, 'italaw181037.pdf'), (0.14168466522678186, 'ita0287_0.pdf')]
# [(1.0, 'ita0026.pdf')]
# [(1.0, 'italaw16109.pdf')]
# [(1.0, 'italaw181348_0.pdf')]
# [(1.0, 'italaw182317.pdf'), (0.346805024576734, 'italaw7118.pdf')]
# [(1.0, 'italaw170200_0.pdf')]
# [(1.0, 'italaw8830.pdf')]
# [(1.0, 'ita0230.pdf')]
# [(1.0, 'italaw7478.pdf')]
# [(1.0, 'italaw8039.pdf')]
# [(1.0, 'italaw11048.pdf')]
# [(1.0, 'ita0378.pdf')]
# [(1.0, 'italaw11921.pdf')]
# [(1.0, 'italaw9131.pdf'), (0.12969194926223143, 'italaw11299.pdf')]
# [(1.0, 'italaw9657.pdf')]
# [(1.0, '180439.pdf')]
# [(1.0, 'italaw182061.pdf')]
# [(1.0, 'italaw11538.pdf')]
# [(1.0, 'italaw9848.pdf')]
# [(1.0, 'italaw11299.pdf'), (0.12969194926223143, 'italaw9131.pdf')]
# [(1.0, 'italaw10187.pdf')]
# [(1.0, 'italaw7681.pdf')]
# [(1.0, 'italaw180869.pdf')]
# [(1.0, 'italaw16509.pdf')]
# [(1.0, 'italaw7118.pdf'), (0.346805024576734, 'italaw182317.pdf')]
# [(1.0, '180401.pdf')]
# [(1.0, 'italaw16092.pdf')]
# [(1.0, 'italaw16086.pdf')]
# [(1.0, 'italaw11931.pdf')]
# [(1.0, 'italaw10420.pdf'), (0.1728301886792453, 'ita0287_0.pdf'), (0.16760450160771703, 'italaw181037.pdf'), (0.1548140043763676, 'italaw11470.pdf')]
# [(1.0, '180603.pdf')]
# [(1.0, 'italaw1294_0.pdf')]
# [(1.0, 'italaw182449.pdf')]
# [(1.0, 'italaw3008.pdf')]
# [(1.0, 'italaw7508.pdf')]
# [(1.0, 'ita0778.pdf')]
# [(1.0, 'italaw16496.pdf')]
# [(1.0, 'italaw9041.pdf')]
# [(1.0, 'italaw7737.pdf')]
# [(1.0, 'italaw8362.pdf')]
# [(1.0, 'italaw10743.pdf')]
# [(1.0, '180574.pdf')]
# [(1.0, 'italaw11461.pdf')]
# [(1.0, 'italaw10794.pdf')]
# [(1.0, 'italaw8389.pdf')]
# [(1.0, '180762.pdf')]
# [(1.0, 'ita0287_0.pdf'), (0.1728301886792453, 'italaw10420.pdf'), (0.17223738062755797, 'italaw181037.pdf'), (0.14168466522678186, 'italaw11470.pdf')]
# [(1.0, 'italaw8883_0.pdf')]
# [(1.0, 'italaw11663.pdf')]
# [(1.0, 'italaw11105.pdf')]
# [(1.0, 'italaw8148.pdf')]
# [(1.0, 'italaw10569.pdf')]
# [(1.0, 'italaw170812.pdf')]
# [(1.0, 'italaw1187.pdf')]
# [(1.0, 'italaw4408_Part6.pdf')]
# [(1.0, 'italaw171339.pdf')]
# [(1.0, 'italaw7744_1.pdf')]
# [(1.0, 'ita0146_0.pdf')]
# [(1.0, 'italaw1232.pdf')]
# [(1.0, 'italaw16520.pdf')]
# [(1.0, 'italaw9108.pdf')]
# [(1.0, 'italaw7131.pdf')]
# [(1.0, 'italaw7657.pdf')]
# [(1.0, '180428.pdf')]
# [(1.0, 'italaw16508.pdf')]
# [(1.0, 'italaw1597.pdf')]
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x47ee for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x48df for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x601e for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x4b08 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3266 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2586 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x278c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# [(1.0, 'italaw1583.pdf')]
# Multiple definitions in dictionary at byte 0x2100 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3af5 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2511 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x40ec for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2f76 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3317 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2be6 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3b64 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2530 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3bf0 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2268 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x30ea for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x31f7 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3c82 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2706 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x306c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2864 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2be5 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x339a for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2f48 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3e50 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x26e4 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2763 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2cec for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3903 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x31a8 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x21a1 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x350a for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3240 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2e09 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3b83 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x307b for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x26a1 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x20e8 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x38e4 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x288f for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# [(1.0, 'italaw11298.pdf'), (0.1920206659012629, 'italaw7046.pdf')]
# [(1.0, 'ita0619.pdf'), (0.2400073678393811, 'italaw16046.pdf')]
# [(1.0, 'italaw8599.pdf')]
# [(1.0, 'italaw16244.pdf')]
# [(1.0, 'italaw10386.pdf')]
# Overwriting cache for 0 65
# [(1.0, 'italaw181989.pdf')]
# [(1.0, 'italaw9452.pdf')]
# [(1.0, 'italaw181037.pdf'), (0.17223738062755797, 'ita0287_0.pdf'), (0.16760450160771703, 'italaw10420.pdf'), (0.15257439773264053, 'italaw11470.pdf')]
# [(1.0, 'italaw16046.pdf'), (0.2400073678393811, 'ita0619.pdf')]
# [(1.0, '180166.pdf')]
# [(1.0, 'italaw10219.pdf')]
# [(1.0, 'italaw1146.pdf')]
# [(1.0, 'italaw170421.pdf')]
# [(1.0, 'ita0035.pdf')]
# [(1.0, 'italaw11488.pdf')]
# [(1.0, 'italaw181341.pdf'), (0.13500393597480975, 'italaw4200.pdf')]
# [(1.0, 'italaw9724.pdf')]
# [(1.0, 'italaw11305.pdf')]
# [(1.0, 'italaw4200.pdf'), (0.13500393597480975, 'italaw181341.pdf')]
# [(1.0, 'italaw16318.pdf')]
# [(1.0, 'italaw3235.pdf')]
# [(1.0, 'italaw9718.pdf')]
# [(1.0, 'italaw7046.pdf'), (0.1920206659012629, 'italaw11298.pdf')]
# [(1.0, 'italaw3220.pdf')]
# [(1.0, 'ita0746.pdf')]
# [(1.0, 'italaw6357_0.pdf')]
# [(1.0, 'italaw10230.pdf')]
# [(1.0, 'italaw170839.pdf')]
# [(1.0, 'italaw170811.pdf')]
# [(1.0, 'italaw182339.pdf')]
# [(1.0, 'italaw10456_0.pdf')]
# [(1.0, 'italaw16279.pdf')]
# [(1.0, 'ita0154.pdf')]

# %% [markdown]
# ## 3. Distributed Streaming Algorithm:
# Faiss + SBERT + LSH system

# %%
# Distributed Faiss + SBERT + LSH system: each bucket has its own Faiss index

from sentence_transformers import SentenceTransformer
from sklearn.random_projection import SparseRandomProjection
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from PyPDF2 import PdfReader
import numpy as np
import faiss
import os
import re
from collections import defaultdict

# ----------------------------
# Preprocessing
# ----------------------------
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s]', '', text)
    tokens = text.split()
    return ' '.join([token for token in tokens if token not in ENGLISH_STOP_WORDS])

def extract_text_from_pdf(pdf_path):
    try:
        reader = PdfReader(pdf_path)
        text = ""
        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:
                text += page_text
        return text
    except Exception as e:
        print(f"[ERROR] Failed to read {pdf_path}: {e}")
        return None

# ----------------------------
# LSH Router
# ----------------------------
class LSHRouter:
    def __init__(self, n_planes=3):
        self.n_planes = n_planes
        self.projection = SparseRandomProjection(n_components=n_planes)

    def fit(self, vectors):
        self.projection.fit(vectors)

    def hash_vector(self, vec):
        projected = self.projection.transform([vec])[0]
        return tuple((projected > 0).astype(int))  # hash as binary vector

# ----------------------------
# Distributed Faiss Engine
# ----------------------------
class DistributedFaissEngine:
    def __init__(self, model_name='all-MiniLM-L6-v2', top_k=5, n_planes=3):
        self.model = SentenceTransformer(model_name) # load embedding model
        self.vector_size = self.model.get_sentence_embedding_dimension()
        self.top_k = top_k
        self.router = LSHRouter(n_planes=n_planes)
        self.bucket_indices = defaultdict(lambda: faiss.IndexFlatIP(self.vector_size))
        self.bucket_docs = defaultdict(list)
        self.doc_vectors = {}

    def add_documents(self, documents):
        vectors = []
        doc_ids = []

        for doc_id, text in documents:
            cleaned = preprocess_text(text)
            vec = self.model.encode(cleaned)
            vec = vec / np.linalg.norm(vec)
            vectors.append(vec)
            doc_ids.append(doc_id)
            self.doc_vectors[doc_id] = vec

        self.router.fit(np.array(vectors))

        for i, doc_id in enumerate(doc_ids):
            vec = vectors[i]
            bucket = self.router.hash_vector(vec)
            self.bucket_indices[bucket].add(np.array([vec]).astype('float32'))
            self.bucket_docs[bucket].append(doc_id)

    def query(self, text):
        cleaned = preprocess_text(text)
        query_vec = self.model.encode(cleaned)
        query_vec = query_vec / np.linalg.norm(query_vec)
        bucket = self.router.hash_vector(query_vec)

        if bucket not in self.bucket_indices:
            return []

        index = self.bucket_indices[bucket]
        doc_ids = self.bucket_docs[bucket]
        D, I = index.search(np.array([query_vec]).astype('float32'), self.top_k)

        return [(doc_ids[i], float(D[0][j])) for j, i in enumerate(I[0]) if i < len(doc_ids)]

# %%
docs_dir = "docs/"
stream_graph = DistributedFaissEngine(top_k=5)

for file in os.listdir(docs_dir):
    if file.endswith(".pdf"):
        file_path = os.path.join(docs_dir, file)
        text = extract_text_from_pdf(file_path)
        if text:
            # Wrap the single (doc_id, text) tuple in a list
            stream_graph.add_documents([(file, text)])
# Out:
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x47ee for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x48df for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x601e for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x4b08 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3266 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2586 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x278c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2100 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3af5 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2511 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x40ec for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2f76 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3317 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2be6 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3b64 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2530 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3bf0 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2268 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x30ea for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x31f7 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3c82 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2706 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x306c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2864 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2be5 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x339a for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2f48 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3e50 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x26e4 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2763 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2cec for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3903 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x31a8 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x21a1 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x350a for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3240 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x2e09 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x3b83 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x307b for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x26a1 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x20e8 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x38e4 for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x288f for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Multiple definitions in dictionary at byte 0x20c for key /Subtype
# Overwriting cache for 0 65

# %%
files
# Out:
# ['.DS_Store',
#  'test_data',
#  'italaw11470.pdf',
#  'ita0026.pdf',
#  'italaw16109.pdf',
#  'italaw181348_0.pdf',
#  'italaw182317.pdf',
#  'italaw170200_0.pdf',
#  'italaw8830.pdf',
#  'ita0230.pdf',
#  'italaw7478.pdf',
#  'italaw8039.pdf',
#  'italaw11048.pdf',
#  'ita0378.pdf',
#  'italaw11921.pdf',
#  'italaw9131.pdf',
#  'italaw9657.pdf',
#  '180439.pdf',
#  'italaw182061.pdf',
#  'italaw11538.pdf',
#  'italaw9848.pdf',
#  'italaw11299.pdf',
#  'italaw10187.pdf',
#  'italaw7681.pdf',
#  'italaw180869.pdf',
#  'italaw16509.pdf',
#  'italaw7118.pdf',
#  '180401.pdf',
#  'italaw16092.pdf',
#  'italaw16086.pdf',
#  'italaw11931.pdf',
#  'italaw10420.pdf',
#  '180603.pdf',
#  'italaw1294_0.pdf',
#  'italaw182449.pdf',
#  'italaw3008.pdf',
#  'italaw7508.pdf',
#  'ita0778.pdf',
#  'italaw16496.pdf',
#  'italaw9041.pdf',
#  'italaw7737.pdf',
#  'italaw8362.pdf',
#  'italaw10743.pdf',
#  '180574.pdf',
#  'italaw11461.pdf',
#  'italaw10794.pdf',
#  'italaw8389.pdf',
#  '180762.pdf',
#  'ita0287_0.pdf',
#  'italaw8883_0.pdf',
#  'italaw11663.pdf',
#  'italaw11105.pdf',
#  'italaw8148.pdf',
#  'italaw10569.pdf',
#  'italaw170812.pdf',
#  'italaw1187.pdf',
#  'italaw4408_Part6.pdf',
#  'italaw171339.pdf',
#  'italaw7744_1.pdf',
#  'ita0146_0.pdf',
#  'italaw1232.pdf',
#  'italaw16520.pdf',
#  'italaw9108.pdf',
#  'italaw7131.pdf',
#  'italaw7657.pdf',
#  '180428.pdf',
#  'italaw16508.pdf',
#  'italaw1597.pdf',
#  'italaw1583.pdf',
#  'italaw11298.pdf',
#  'ita0619.pdf',
#  'italaw8599.pdf',
#  'italaw16244.pdf',
#  'italaw10386.pdf',
#  'italaw181989.pdf',
#  'italaw9452.pdf',
#  'italaw181037.pdf',
#  'italaw16046.pdf',
#  '180166.pdf',
#  'italaw10219.pdf',
#  'italaw1146.pdf',
#  'italaw170421.pdf',
#  'ita0035.pdf',
#  'italaw11488.pdf',
#  'italaw181341.pdf',
#  'italaw9724.pdf',
#  'italaw11305.pdf',
#  'italaw4200.pdf',
#  'italaw16318.pdf',
#  'italaw3235.pdf',
#  'italaw9718.pdf',
#  'italaw7046.pdf',
#  'italaw3220.pdf',
#  'ita0746.pdf',
#  'italaw6357_0.pdf',
#  'italaw10230.pdf',
#  'italaw170839.pdf',
#  'italaw170811.pdf',
#  'italaw182339.pdf',
#  'italaw10456_0.pdf',
#  'italaw16279.pdf',
#  'ita0154.pdf']

# %%
query_file = "docs/italaw170811.pdf"
query_text = extract_text_from_pdf(query_file)

if query_text:
    results = stream_graph.query(query_text)
    for doc_id, score in results:
        print(f"{doc_id} — cosine similarity: {score:.3f}")
# Out:
# 180574.pdf — cosine similarity: 0.706
# italaw3235.pdf — cosine similarity: 0.704
# italaw3008.pdf — cosine similarity: 0.625
# italaw16520.pdf — cosine similarity: 0.598
# italaw7737.pdf — cosine similarity: 0.595

# %%
results
# Out:
# []
